# %% [markdown]
# # AdaBoost y Gradient boosting con árboles en un dataset de detección de spam
#
# Árboles de decisión y todos los ensembles propuestos funcionan en la práctica muy bien en datos tabulares como puede ser el problema de reconocimiento de spam en mails.
#
# Se propone pues emplear el dataset id=44 de openml de detección de Spam. Son un total de 4601 muestras con 57 características.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)
# Out:
# (4601, 57)
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %% [markdown]
# ## AdaBoost
#
# Probemos el clasificador de AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

ab = AdaBoostClassifier()

acc=ab.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 93.8%

# %% [markdown]
# **Ejercicio** Teniendo en cuenta la documentación [AdaBoost](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html) prueba mediante grid search a encontrar mejores parámetros.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier

G = {"estimator__max_depth" : [4,6,8,10], "n_estimators": [100,200,250]}

clf=AdaBoostClassifier(estimator = DecisionTreeClassifier())

GS = GridSearchCV(clf,G, scoring='accuracy', refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START estimator__max_depth=4, n_estimators=100...................
# [CV 1/5; 1/12] END estimator__max_depth=4, n_estimators=100;, score=0.952 total time=   2.4s
# [CV 2/5; 1/12] START estimator__max_depth=4, n_estimators=100...................
# [CV 2/5; 1/12] END estimator__max_depth=4, n_estimators=100;, score=0.950 total time=   2.0s
# [CV 3/5; 1/12] START estimator__max_depth=4, n_estimators=100...................
# [CV 3/5; 1/12] END estimator__max_depth=4, n_estimators=100;, score=0.951 total time=   2.1s
# [CV 4/5; 1/12] START estimator__max_depth=4, n_estimators=100...................
# [CV 4/5; 1/12] END estimator__max_depth=4, n_estimators=100;, score=0.936 total time=   2.0s
# [CV 5/5; 1/12] START estimator__max_depth=4, n_estimators=100...................
# [CV 5/5; 1/12] END estimator__max_depth=4, n_estimators=100;, score=0.944 total time=   2.6s
# [CV 1/5; 2/12] START estimator__max_depth=4, n_estimators=200...................
# [CV 1/5; 2/12] END estimator__max_depth=4, n_estimators=200;, score=0.959 total time=   4.4s
# [CV 2/5; 2/12] START estimator__max_depth=4, n_estimators=200...................
# [CV 2/5; 2/12] END estimator__max_depth=4, n_estimators=200;, score=0.955 total time=   3.9s
# [CV 3/5; 2/12] START estimator__max_depth=4, n_estimators=200...................
# [CV 3/5; 2/12] END estimator__max_depth=4, n_estimators=200;, score=0.965 total time=   4.7s
# [CV 4/5; 2/12] START estimator__max_depth=4, n_estimators=200...................
# [CV 4/5; 2/12] END estimator__max_depth=4, n_estimators=200;, score=0.942 total time=   4.3s
# [CV 5/5; 2/12] START estimator__max_depth=4, n_estimators=200...................
# [CV 5/5; 2/12] END estimator__max_depth=4, n_estimators=200;, score=0.944 total time=   5.1s
# [CV 1/5; 3/12] START estimator__max_depth=4, n_estimators=250...................
# [CV 1/5; 3/12] END estimator__max_depth=4, n_estimators=250;, score=0.958 total time=   7.2s
# [CV 2/5; 3/12] START estimator__max_depth=4, n_estimators=250...................
# [CV 2/5; 3/12] END estimator__max_depth=4, n_estimators=250;, score=0.954 total time=   5.7s
# [CV 3/5; 3/12] START estimator__max_depth=4, n_estimators=250...................
# [CV 3/5; 3/12] END estimator__max_depth=4, n_estimators=250;, score=0.962 total time=   5.7s
# [CV 4/5; 3/12] START estimator__max_depth=4, n_estimators=250...................
# [CV 4/5; 3/12] END estimator__max_depth=4, n_estimators=250;, score=0.943 total time=   5.0s
# [CV 5/5; 3/12] START estimator__max_depth=4, n_estimators=250...................
# [CV 5/5; 3/12] END estimator__max_depth=4, n_estimators=250;, score=0.943 total time=  10.5s
# [CV 1/5; 4/12] START estimator__max_depth=6, n_estimators=100...................
# [CV 1/5; 4/12] END estimator__max_depth=6, n_estimators=100;, score=0.951 total time=   2.8s
# [CV 2/5; 4/12] START estimator__max_depth=6, n_estimators=100...................
# [CV 2/5; 4/12] END estimator__max_depth=6, n_estimators=100;, score=0.957 total time=   2.6s
# [CV 3/5; 4/12] START estimator__max_depth=6, n_estimators=100...................
# [CV 3/5; 4/12] END estimator__max_depth=6, n_estimators=100;, score=0.967 total time=   5.2s
# [CV 4/5; 4/12] START estimator__max_depth=6, n_estimators=100...................
# [CV 4/5; 4/12] END estimator__max_depth=6, n_estimators=100;, score=0.942 total time=   3.2s
# [CV 5/5; 4/12] START estimator__max_depth=6, n_estimators=100...................
# [CV 5/5; 4/12] END estimator__max_depth=6, n_estimators=100;, score=0.938 total time=   4.4s
# [CV 1/5; 5/12] START estimator__max_depth=6, n_estimators=200...................
# [CV 1/5; 5/12] END estimator__max_depth=6, n_estimators=200;, score=0.952 total time=   7.8s
# [CV 2/5; 5/12] START estimator__max_depth=6, n_estimators=200...................
# [CV 2/5; 5/12] END estimator__max_depth=6, n_estimators=200;, score=0.958 total time=   6.3s
# [CV 3/5; 5/12] START estimator__max_depth=6, n_estimators=200...................
# [CV 3/5; 5/12] END estimator__max_depth=6, n_estimators=200;, score=0.965 total time=   6.2s
# [CV 4/5; 5/12] START estimator__max_depth=6, n_estimators=200...................
# [CV 4/5; 5/12] END estimator__max_depth=6, n_estimators=200;, score=0.938 total time=   5.9s
# [CV 5/5; 5/12] START estimator__max_depth=6, n_estimators=200...................
# [CV 5/5; 5/12] END estimator__max_depth=6, n_estimators=200;, score=0.944 total time=   6.2s
# [CV 1/5; 6/12] START estimator__max_depth=6, n_estimators=250...................
# [CV 1/5; 6/12] END estimator__max_depth=6, n_estimators=250;, score=0.957 total time=   7.3s
# [CV 2/5; 6/12] START estimator__max_depth=6, n_estimators=250...................
# [CV 2/5; 6/12] END estimator__max_depth=6, n_estimators=250;, score=0.954 total time=   7.8s
# [CV 3/5; 6/12] START estimator__max_depth=6, n_estimators=250...................
# [CV 3/5; 6/12] END estimator__max_depth=6, n_estimators=250;, score=0.958 total time=   6.6s
# [CV 4/5; 6/12] START estimator__max_depth=6, n_estimators=250...................
# [CV 4/5; 6/12] END estimator__max_depth=6, n_estimators=250;, score=0.938 total time=   7.3s
# [CV 5/5; 6/12] START estimator__max_depth=6, n_estimators=250...................
# [CV 5/5; 6/12] END estimator__max_depth=6, n_estimators=250;, score=0.947 total time=   7.1s
# [CV 1/5; 7/12] START estimator__max_depth=8, n_estimators=100...................
# [CV 1/5; 7/12] END estimator__max_depth=8, n_estimators=100;, score=0.954 total time=   5.3s
# [CV 2/5; 7/12] START estimator__max_depth=8, n_estimators=100...................
# [CV 2/5; 7/12] END estimator__max_depth=8, n_estimators=100;, score=0.946 total time=   3.5s
# [CV 3/5; 7/12] START estimator__max_depth=8, n_estimators=100...................
# [CV 3/5; 7/12] END estimator__max_depth=8, n_estimators=100;, score=0.961 total time=   5.9s
# [CV 4/5; 7/12] START estimator__max_depth=8, n_estimators=100...................
# [CV 4/5; 7/12] END estimator__max_depth=8, n_estimators=100;, score=0.939 total time=   4.4s
# [CV 5/5; 7/12] START estimator__max_depth=8, n_estimators=100...................
# [CV 5/5; 7/12] END estimator__max_depth=8, n_estimators=100;, score=0.946 total time=   4.5s
# [CV 1/5; 8/12] START estimator__max_depth=8, n_estimators=200...................
# [CV 1/5; 8/12] END estimator__max_depth=8, n_estimators=200;, score=0.958 total time=   7.8s
# [CV 2/5; 8/12] START estimator__max_depth=8, n_estimators=200...................
# [CV 2/5; 8/12] END estimator__max_depth=8, n_estimators=200;, score=0.954 total time=   8.8s
# [CV 3/5; 8/12] START estimator__max_depth=8, n_estimators=200...................
# [CV 3/5; 8/12] END estimator__max_depth=8, n_estimators=200;, score=0.961 total time=   7.4s
# [CV 4/5; 8/12] START estimator__max_depth=8, n_estimators=200...................
# [CV 4/5; 8/12] END estimator__max_depth=8, n_estimators=200;, score=0.943 total time=   7.7s
# [CV 5/5; 8/12] START estimator__max_depth=8, n_estimators=200...................
# [CV 5/5; 8/12] END estimator__max_depth=8, n_estimators=200;, score=0.948 total time=   6.6s
# [CV 1/5; 9/12] START estimator__max_depth=8, n_estimators=250...................
# [CV 1/5; 9/12] END estimator__max_depth=8, n_estimators=250;, score=0.961 total time=   9.5s
# [CV 2/5; 9/12] START estimator__max_depth=8, n_estimators=250...................
# [CV 2/5; 9/12] END estimator__max_depth=8, n_estimators=250;, score=0.950 total time=   8.5s
# [CV 3/5; 9/12] START estimator__max_depth=8, n_estimators=250...................
# [CV 3/5; 9/12] END estimator__max_depth=8, n_estimators=250;, score=0.965 total time=   8.0s
# [CV 4/5; 9/12] START estimator__max_depth=8, n_estimators=250...................
# [CV 4/5; 9/12] END estimator__max_depth=8, n_estimators=250;, score=0.943 total time=   8.9s
# [CV 5/5; 9/12] START estimator__max_depth=8, n_estimators=250...................
# [CV 5/5; 9/12] END estimator__max_depth=8, n_estimators=250;, score=0.950 total time=   8.9s
# [CV 1/5; 10/12] START estimator__max_depth=10, n_estimators=100.................
# [CV 1/5; 10/12] END estimator__max_depth=10, n_estimators=100;, score=0.950 total time=   4.0s
# [CV 2/5; 10/12] START estimator__max_depth=10, n_estimators=100.................
# [CV 2/5; 10/12] END estimator__max_depth=10, n_estimators=100;, score=0.961 total time=   3.6s
# [CV 3/5; 10/12] START estimator__max_depth=10, n_estimators=100.................
# [CV 3/5; 10/12] END estimator__max_depth=10, n_estimators=100;, score=0.958 total time=   5.1s
# [CV 4/5; 10/12] START estimator__max_depth=10, n_estimators=100.................
# [CV 4/5; 10/12] END estimator__max_depth=10, n_estimators=100;, score=0.940 total time=   3.9s
# [CV 5/5; 10/12] START estimator__max_depth=10, n_estimators=100.................
# [CV 5/5; 10/12] END estimator__max_depth=10, n_estimators=100;, score=0.950 total time=   3.9s
# [CV 1/5; 11/12] START estimator__max_depth=10, n_estimators=200.................
# [CV 1/5; 11/12] END estimator__max_depth=10, n_estimators=200;, score=0.955 total time=   8.8s
# [CV 2/5; 11/12] START estimator__max_depth=10, n_estimators=200.................
# [CV 2/5; 11/12] END estimator__max_depth=10, n_estimators=200;, score=0.966 total time=   7.6s
# [CV 3/5; 11/12] START estimator__max_depth=10, n_estimators=200.................
# [CV 3/5; 11/12] END estimator__max_depth=10, n_estimators=200;, score=0.963 total time=   7.7s
# [CV 4/5; 11/12] START estimator__max_depth=10, n_estimators=200.................
# [CV 4/5; 11/12] END estimator__max_depth=10, n_estimators=200;, score=0.935 total time=   9.0s
# [CV 5/5; 11/12] START estimator__max_depth=10, n_estimators=200.................
# [CV 5/5; 11/12] END estimator__max_depth=10, n_estimators=200;, score=0.950 total time=  11.5s
# [CV 1/5; 12/12] START estimator__max_depth=10, n_estimators=250.................
# [CV 1/5; 12/12] END estimator__max_depth=10, n_estimators=250;, score=0.957 total time=  11.8s
# [CV 2/5; 12/12] START estimator__max_depth=10, n_estimators=250.................
# [CV 2/5; 12/12] END estimator__max_depth=10, n_estimators=250;, score=0.959 total time=   9.0s
# [CV 3/5; 12/12] START estimator__max_depth=10, n_estimators=250.................
# [CV 3/5; 12/12] END estimator__max_depth=10, n_estimators=250;, score=0.959 total time=  10.1s
# [CV 4/5; 12/12] START estimator__max_depth=10, n_estimators=250.................
# [CV 4/5; 12/12] END estimator__max_depth=10, n_estimators=250;, score=0.938 total time=  10.5s
# [CV 5/5; 12/12] START estimator__max_depth=10, n_estimators=250.................
# [CV 5/5; 12/12] END estimator__max_depth=10, n_estimators=250;, score=0.944 total time=  13.0s
# Precisión: 95.0% con {'estimator__max_depth': 10, 'n_estimators': 200}

# %% [markdown]
# ## GradientBoostingClassifier
#
# Probemos el clasificador Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()

acc=gb.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 95.2%

# %% [markdown]
# Los principales parámetros del GradientBoosting son:
# * n_estimators (100)
# * max_depth (3)
# * max_features
#
# **Ejercicio** prueba diferentes valores (lógicos) de estos parámetros mediante GridSearch.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier

clf=GradientBoostingClassifier()

G = {"max_depth" : [4,6,8,10], "max_features" : [0.25, 0.5, 1.0], "n_estimators": [100,200,250]}


GS = GridSearchCV(clf,G, scoring='accuracy', refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5; 1/36] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 1/5; 1/36] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.946 total time=   0.6s
# [CV 2/5; 1/36] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 2/5; 1/36] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.944 total time=   0.7s
# [CV 3/5; 1/36] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 3/5; 1/36] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.959 total time=   0.7s
# [CV 4/5; 1/36] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 4/5; 1/36] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.939 total time=   0.8s
# [CV 5/5; 1/36] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 5/5; 1/36] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.954 total time=   0.7s
# [CV 1/5; 2/36] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 1/5; 2/36] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.948 total time=   1.0s
# [CV 2/5; 2/36] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 2/5; 2/36] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.951 total time=   1.0s
# [CV 3/5; 2/36] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 3/5; 2/36] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.961 total time=   1.0s
# [CV 4/5; 2/36] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 4/5; 2/36] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.946 total time=   1.0s
# [CV 5/5; 2/36] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 5/5; 2/36] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.958 total time=   1.0s
# [CV 1/5; 3/36] START max_depth=4, max_features=0.25, n_estimators=250...........
# [CV 1/5; 3/36] END max_depth=4, max_features=0.25, n_estimators=250;, score=0.951 total time=   1.3s
# [CV 2/5; 3/36] START max_depth=4, max_features=0.25, n_estimators=250...........
# [CV 2/5; 3/36] END max_depth=4, max_features=0.25, n_estimators=250;, score=0.951 total time=   1.3s
# [CV 3/5; 3/36] START max_depth=4, max_features=0.25, n_estimators=250...........
# [CV 3/5; 3/36] END max_depth=4, max_features=0.25, n_estimators=250;, score=0.963 total time=   1.3s
# [CV 4/5; 3/36] START max_depth=4, max_features=0.25, n_estimators=250...........
# [CV 4/5; 3/36] END max_depth=4, max_features=0.25, n_estimators=250;, score=0.944 total time=   1.3s
# [CV 5/5; 3/36] START max_depth=4, max_features=0.25, n_estimators=250...........
# [CV 5/5; 3/36] END max_depth=4, max_features=0.25, n_estimators=250;, score=0.961 total time=   1.8s
# [CV 1/5; 4/36] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 1/5; 4/36] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.943 total time=   1.1s
# [CV 2/5; 4/36] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 2/5; 4/36] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.947 total time=   0.9s
# [CV 3/5; 4/36] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 3/5; 4/36] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.955 total time=   0.9s
# [CV 4/5; 4/36] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 4/5; 4/36] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.935 total time=   0.9s
# [CV 5/5; 4/36] START max_depth=4, max_features=0.5, n_estimators=100............
# [CV 5/5; 4/36] END max_depth=4, max_features=0.5, n_estimators=100;, score=0.958 total time=   0.9s
# [CV 1/5; 5/36] START max_depth=4, max_features=0.5, n_estimators=200............
# [CV 1/5; 5/36] END max_depth=4, max_features=0.5, n_estimators=200;, score=0.951 total time=   1.8s
# [CV 2/5; 5/36] START max_depth=4, max_features=0.5, n_estimators=200............
# [CV 2/5; 5/36] END max_depth=4, max_features=0.5, n_estimators=200;, score=0.952 total time=   1.7s
# [CV 3/5; 5/36] START max_depth=4, max_features=0.5, n_estimators=200............
# [CV 3/5; 5/36] END max_depth=4, max_features=0.5, n_estimators=200;, score=0.962 total time=   1.8s
# [CV 4/5; 5/36] START max_depth=4, max_features=0.5, n_estimators=200............
# [CV 4/5; 5/36] END max_depth=4, max_features=0.5, n_estimators=200;, score=0.942 total time=   2.1s
# [CV 5/5; 5/36] START max_depth=4, max_features=0.5, n_estimators=200............
# [CV 5/5; 5/36] END max_depth=4, max_features=0.5, n_estimators=200;, score=0.958 total time=   2.2s
# [CV 1/5; 6/36] START max_depth=4, max_features=0.5, n_estimators=250............
# [CV 1/5; 6/36] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.947 total time=   2.2s
# [CV 2/5; 6/36] START max_depth=4, max_features=0.5, n_estimators=250............
# [CV 2/5; 6/36] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.952 total time=   2.2s
# [CV 3/5; 6/36] START max_depth=4, max_features=0.5, n_estimators=250............
# [CV 3/5; 6/36] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.958 total time=   2.2s
# [CV 4/5; 6/36] START max_depth=4, max_features=0.5, n_estimators=250............
# [CV 4/5; 6/36] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.946 total time=   2.2s
# [CV 5/5; 6/36] START max_depth=4, max_features=0.5, n_estimators=250............
# [CV 5/5; 6/36] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.961 total time=   2.7s
# [CV 1/5; 7/36] START max_depth=4, max_features=1.0, n_estimators=100............
# [CV 1/5; 7/36] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.948 total time=   1.9s
# [CV 2/5; 7/36] START max_depth=4, max_features=1.0, n_estimators=100............
# [CV 2/5; 7/36] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.946 total time=   1.6s
# [CV 3/5; 7/36] START max_depth=4, max_features=1.0, n_estimators=100............
# [CV 3/5; 7/36] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.957 total time=   1.6s
# [CV 4/5; 7/36] START max_depth=4, max_features=1.0, n_estimators=100............
# [CV 4/5; 7/36] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.939 total time=   1.6s
# [CV 5/5; 7/36] START max_depth=4, max_features=1.0, n_estimators=100............
# [CV 5/5; 7/36] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.954 total time=   1.6s
# [CV 1/5; 8/36] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 1/5; 8/36] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.952 total time=   3.4s
# [CV 2/5; 8/36] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 2/5; 8/36] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.948 total time=   3.8s
# [CV 3/5; 8/36] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 3/5; 8/36] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.957 total time=   3.2s
# [CV 4/5; 8/36] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 4/5; 8/36] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.944 total time=   3.2s
# [CV 5/5; 8/36] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 5/5; 8/36] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.958 total time=   3.8s
# [CV 1/5; 9/36] START max_depth=4, max_features=1.0, n_estimators=250............
# [CV 1/5; 9/36] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.955 total time=   4.3s
# [CV 2/5; 9/36] START max_depth=4, max_features=1.0, n_estimators=250............
# [CV 2/5; 9/36] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.951 total time=   4.0s
# [CV 3/5; 9/36] START max_depth=4, max_features=1.0, n_estimators=250............
# [CV 3/5; 9/36] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.958 total time=   4.5s
# [CV 4/5; 9/36] START max_depth=4, max_features=1.0, n_estimators=250............
# [CV 4/5; 9/36] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.946 total time=   4.2s
# [CV 5/5; 9/36] START max_depth=4, max_features=1.0, n_estimators=250............
# [CV 5/5; 9/36] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.958 total time=   4.0s
# [CV 1/5; 10/36] START max_depth=6, max_features=0.25, n_estimators=100..........
# [CV 1/5; 10/36] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.948 total time=   0.8s
# [CV 2/5; 10/36] START max_depth=6, max_features=0.25, n_estimators=100..........
# [CV 2/5; 10/36] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.955 total time=   0.8s
# [CV 3/5; 10/36] START max_depth=6, max_features=0.25, n_estimators=100..........
# [CV 3/5; 10/36] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.963 total time=   0.8s
# [CV 4/5; 10/36] START max_depth=6, max_features=0.25, n_estimators=100..........
# [CV 4/5; 10/36] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.948 total time=   0.9s
# [CV 5/5; 10/36] START max_depth=6, max_features=0.25, n_estimators=100..........
# [CV 5/5; 10/36] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.959 total time=   1.1s
# [CV 1/5; 11/36] START max_depth=6, max_features=0.25, n_estimators=200..........
# [CV 1/5; 11/36] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.958 total time=   1.8s
# [CV 2/5; 11/36] START max_depth=6, max_features=0.25, n_estimators=200..........
# [CV 2/5; 11/36] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.959 total time=   1.5s
# [CV 3/5; 11/36] START max_depth=6, max_features=0.25, n_estimators=200..........
# [CV 3/5; 11/36] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.967 total time=   1.5s
# [CV 4/5; 11/36] START max_depth=6, max_features=0.25, n_estimators=200..........
# [CV 4/5; 11/36] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.950 total time=   1.5s
# [CV 5/5; 11/36] START max_depth=6, max_features=0.25, n_estimators=200..........
# [CV 5/5; 11/36] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.961 total time=   1.5s
# [CV 1/5; 12/36] START max_depth=6, max_features=0.25, n_estimators=250..........
# [CV 1/5; 12/36] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.955 total time=   1.9s
# [CV 2/5; 12/36] START max_depth=6, max_features=0.25, n_estimators=250..........
# [CV 2/5; 12/36] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.962 total time=   2.1s
# [CV 3/5; 12/36] START max_depth=6, max_features=0.25, n_estimators=250..........
# [CV 3/5; 12/36] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.967 total time=   2.8s
# [CV 4/5; 12/36] START max_depth=6, max_features=0.25, n_estimators=250..........
# [CV 4/5; 12/36] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.946 total time=   2.3s
# [CV 5/5; 12/36] START max_depth=6, max_features=0.25, n_estimators=250..........
# [CV 5/5; 12/36] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.962 total time=   1.8s
# [CV 1/5; 13/36] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 1/5; 13/36] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.950 total time=   1.3s
# [CV 2/5; 13/36] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 2/5; 13/36] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.958 total time=   1.3s
# [CV 3/5; 13/36] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 3/5; 13/36] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.958 total time=   1.3s
# [CV 4/5; 13/36] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 4/5; 13/36] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.942 total time=   1.3s
# [CV 5/5; 13/36] START max_depth=6, max_features=0.5, n_estimators=100...........
# [CV 5/5; 13/36] END max_depth=6, max_features=0.5, n_estimators=100;, score=0.958 total time=   1.8s
# [CV 1/5; 14/36] START max_depth=6, max_features=0.5, n_estimators=200...........
# [CV 1/5; 14/36] END max_depth=6, max_features=0.5, n_estimators=200;, score=0.952 total time=   2.8s
# [CV 2/5; 14/36] START max_depth=6, max_features=0.5, n_estimators=200...........
# [CV 2/5; 14/36] END max_depth=6, max_features=0.5, n_estimators=200;, score=0.959 total time=   2.6s
# [CV 3/5; 14/36] START max_depth=6, max_features=0.5, n_estimators=200...........
# [CV 3/5; 14/36] END max_depth=6, max_features=0.5, n_estimators=200;, score=0.969 total time=   2.6s
# [CV 4/5; 14/36] START max_depth=6, max_features=0.5, n_estimators=200...........
# [CV 4/5; 14/36] END max_depth=6, max_features=0.5, n_estimators=200;, score=0.946 total time=   2.5s
# [CV 5/5; 14/36] START max_depth=6, max_features=0.5, n_estimators=200...........
# [CV 5/5; 14/36] END max_depth=6, max_features=0.5, n_estimators=200;, score=0.961 total time=   3.3s
# [CV 1/5; 15/36] START max_depth=6, max_features=0.5, n_estimators=250...........
# [CV 1/5; 15/36] END max_depth=6, max_features=0.5, n_estimators=250;, score=0.954 total time=   3.2s
# [CV 2/5; 15/36] START max_depth=6, max_features=0.5, n_estimators=250...........
# [CV 2/5; 15/36] END max_depth=6, max_features=0.5, n_estimators=250;, score=0.950 total time=   3.2s
# [CV 3/5; 15/36] START max_depth=6, max_features=0.5, n_estimators=250...........
# [CV 3/5; 15/36] END max_depth=6, max_features=0.5, n_estimators=250;, score=0.969 total time=   3.2s
# [CV 4/5; 15/36] START max_depth=6, max_features=0.5, n_estimators=250...........
# [CV 4/5; 15/36] END max_depth=6, max_features=0.5, n_estimators=250;, score=0.944 total time=   3.9s
# [CV 5/5; 15/36] START max_depth=6, max_features=0.5, n_estimators=250...........
# [CV 5/5; 15/36] END max_depth=6, max_features=0.5, n_estimators=250;, score=0.961 total time=   3.2s
# [CV 1/5; 16/36] START max_depth=6, max_features=1.0, n_estimators=100...........
# [CV 1/5; 16/36] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.950 total time=   2.4s
# [CV 2/5; 16/36] START max_depth=6, max_features=1.0, n_estimators=100...........
# [CV 2/5; 16/36] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.944 total time=   2.4s
# [CV 3/5; 16/36] START max_depth=6, max_features=1.0, n_estimators=100...........
# [CV 3/5; 16/36] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.955 total time=   2.9s
# [CV 4/5; 16/36] START max_depth=6, max_features=1.0, n_estimators=100...........
# [CV 4/5; 16/36] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.947 total time=   2.6s
# [CV 5/5; 16/36] START max_depth=6, max_features=1.0, n_estimators=100...........
# [CV 5/5; 16/36] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.957 total time=   2.4s
# [CV 1/5; 17/36] START max_depth=6, max_features=1.0, n_estimators=200...........
# [CV 1/5; 17/36] END max_depth=6, max_features=1.0, n_estimators=200;, score=0.950 total time=   4.8s
# [CV 2/5; 17/36] START max_depth=6, max_features=1.0, n_estimators=200...........
# [CV 2/5; 17/36] END max_depth=6, max_features=1.0, n_estimators=200;, score=0.955 total time=   5.5s
# [CV 3/5; 17/36] START max_depth=6, max_features=1.0, n_estimators=200...........
# [CV 3/5; 17/36] END max_depth=6, max_features=1.0, n_estimators=200;, score=0.963 total time=   4.8s
# [CV 4/5; 17/36] START max_depth=6, max_features=1.0, n_estimators=200...........
# [CV 4/5; 17/36] END max_depth=6, max_features=1.0, n_estimators=200;, score=0.950 total time=   5.2s
# [CV 5/5; 17/36] START max_depth=6, max_features=1.0, n_estimators=200...........
# [CV 5/5; 17/36] END max_depth=6, max_features=1.0, n_estimators=200;, score=0.961 total time=   4.9s
# [CV 1/5; 18/36] START max_depth=6, max_features=1.0, n_estimators=250...........
# [CV 1/5; 18/36] END max_depth=6, max_features=1.0, n_estimators=250;, score=0.955 total time=   6.0s
# [CV 2/5; 18/36] START max_depth=6, max_features=1.0, n_estimators=250...........
# [CV 2/5; 18/36] END max_depth=6, max_features=1.0, n_estimators=250;, score=0.954 total time=   6.6s
# [CV 3/5; 18/36] START max_depth=6, max_features=1.0, n_estimators=250...........
# [CV 3/5; 18/36] END max_depth=6, max_features=1.0, n_estimators=250;, score=0.969 total time=   5.9s
# [CV 4/5; 18/36] START max_depth=6, max_features=1.0, n_estimators=250...........
# [CV 4/5; 18/36] END max_depth=6, max_features=1.0, n_estimators=250;, score=0.950 total time=   6.6s
# [CV 5/5; 18/36] START max_depth=6, max_features=1.0, n_estimators=250...........
# [CV 5/5; 18/36] END max_depth=6, max_features=1.0, n_estimators=250;, score=0.962 total time=   5.9s
# [CV 1/5; 19/36] START max_depth=8, max_features=0.25, n_estimators=100..........
# [CV 1/5; 19/36] END max_depth=8, max_features=0.25, n_estimators=100;, score=0.954 total time=   1.5s
# [CV 2/5; 19/36] START max_depth=8, max_features=0.25, n_estimators=100..........
# [CV 2/5; 19/36] END max_depth=8, max_features=0.25, n_estimators=100;, score=0.955 total time=   1.5s
# [CV 3/5; 19/36] START max_depth=8, max_features=0.25, n_estimators=100..........
# [CV 3/5; 19/36] END max_depth=8, max_features=0.25, n_estimators=100;, score=0.965 total time=   1.1s
# [CV 4/5; 19/36] START max_depth=8, max_features=0.25, n_estimators=100..........
# [CV 4/5; 19/36] END max_depth=8, max_features=0.25, n_estimators=100;, score=0.950 total time=   1.1s
# [CV 5/5; 19/36] START max_depth=8, max_features=0.25, n_estimators=100..........
# [CV 5/5; 19/36] END max_depth=8, max_features=0.25, n_estimators=100;, score=0.961 total time=   1.1s
# [CV 1/5; 20/36] START max_depth=8, max_features=0.25, n_estimators=200..........
# [CV 1/5; 20/36] END max_depth=8, max_features=0.25, n_estimators=200;, score=0.952 total time=   2.1s
# [CV 2/5; 20/36] START max_depth=8, max_features=0.25, n_estimators=200..........
# [CV 2/5; 20/36] END max_depth=8, max_features=0.25, n_estimators=200;, score=0.958 total time=   2.1s
# [CV 3/5; 20/36] START max_depth=8, max_features=0.25, n_estimators=200..........
# [CV 3/5; 20/36] END max_depth=8, max_features=0.25, n_estimators=200;, score=0.971 total time=   2.1s
# [CV 4/5; 20/36] START max_depth=8, max_features=0.25, n_estimators=200..........
# [CV 4/5; 20/36] END max_depth=8, max_features=0.25, n_estimators=200;, score=0.950 total time=   2.8s
# [CV 5/5; 20/36] START max_depth=8, max_features=0.25, n_estimators=200..........
# [CV 5/5; 20/36] END max_depth=8, max_features=0.25, n_estimators=200;, score=0.963 total time=   2.1s
# [CV 1/5; 21/36] START max_depth=8, max_features=0.25, n_estimators=250..........
# [CV 1/5; 21/36] END max_depth=8, max_features=0.25, n_estimators=250;, score=0.962 total time=   2.6s
# [CV 2/5; 21/36] START max_depth=8, max_features=0.25, n_estimators=250..........
# [CV 2/5; 21/36] END max_depth=8, max_features=0.25, n_estimators=250;, score=0.959 total time=   2.6s
# [CV 3/5; 21/36] START max_depth=8, max_features=0.25, n_estimators=250..........
# [CV 3/5; 21/36] END max_depth=8, max_features=0.25, n_estimators=250;, score=0.971 total time=   2.6s
# [CV 4/5; 21/36] START max_depth=8, max_features=0.25, n_estimators=250..........
# [CV 4/5; 21/36] END max_depth=8, max_features=0.25, n_estimators=250;, score=0.952 total time=   3.4s
# [CV 5/5; 21/36] START max_depth=8, max_features=0.25, n_estimators=250..........
# [CV 5/5; 21/36] END max_depth=8, max_features=0.25, n_estimators=250;, score=0.961 total time=   2.6s
# [CV 1/5; 22/36] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 1/5; 22/36] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.952 total time=   1.8s
# [CV 2/5; 22/36] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 2/5; 22/36] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.947 total time=   1.8s
# [CV 3/5; 22/36] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 3/5; 22/36] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.961 total time=   1.8s
# [CV 4/5; 22/36] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 4/5; 22/36] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.950 total time=   1.8s
# [CV 5/5; 22/36] START max_depth=8, max_features=0.5, n_estimators=100...........
# [CV 5/5; 22/36] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.959 total time=   2.5s
# [CV 1/5; 23/36] START max_depth=8, max_features=0.5, n_estimators=200...........
# [CV 1/5; 23/36] END max_depth=8, max_features=0.5, n_estimators=200;, score=0.955 total time=   3.4s
# [CV 2/5; 23/36] START max_depth=8, max_features=0.5, n_estimators=200...........
# [CV 2/5; 23/36] END max_depth=8, max_features=0.5, n_estimators=200;, score=0.962 total time=   3.4s
# [CV 3/5; 23/36] START max_depth=8, max_features=0.5, n_estimators=200...........
# [CV 3/5; 23/36] END max_depth=8, max_features=0.5, n_estimators=200;, score=0.967 total time=   3.6s
# [CV 4/5; 23/36] START max_depth=8, max_features=0.5, n_estimators=200...........
# [CV 4/5; 23/36] END max_depth=8, max_features=0.5, n_estimators=200;, score=0.950 total time=   4.1s
# [CV 5/5; 23/36] START max_depth=8, max_features=0.5, n_estimators=200...........
# [CV 5/5; 23/36] END max_depth=8, max_features=0.5, n_estimators=200;, score=0.961 total time=   3.4s
# [CV 1/5; 24/36] START max_depth=8, max_features=0.5, n_estimators=250...........
# [CV 1/5; 24/36] END max_depth=8, max_features=0.5, n_estimators=250;, score=0.958 total time=   4.3s
# [CV 2/5; 24/36] START max_depth=8, max_features=0.5, n_estimators=250...........
# [CV 2/5; 24/36] END max_depth=8, max_features=0.5, n_estimators=250;, score=0.957 total time=   5.1s
# [CV 3/5; 24/36] START max_depth=8, max_features=0.5, n_estimators=250...........
# [CV 3/5; 24/36] END max_depth=8, max_features=0.5, n_estimators=250;, score=0.966 total time=   4.3s
# [CV 4/5; 24/36] START max_depth=8, max_features=0.5, n_estimators=250...........
# [CV 4/5; 24/36] END max_depth=8, max_features=0.5, n_estimators=250;, score=0.946 total time=   4.5s
# [CV 5/5; 24/36] START max_depth=8, max_features=0.5, n_estimators=250...........
# [CV 5/5; 24/36] END max_depth=8, max_features=0.5, n_estimators=250;, score=0.959 total time=   4.8s
# [CV 1/5; 25/36] START max_depth=8, max_features=1.0, n_estimators=100...........
# [CV 1/5; 25/36] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.951 total time=   3.2s
# [CV 2/5; 25/36] START max_depth=8, max_features=1.0, n_estimators=100...........
# [CV 2/5; 25/36] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.948 total time=   3.2s
# [CV 3/5; 25/36] START max_depth=8, max_features=1.0, n_estimators=100...........
# [CV 3/5; 25/36] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.966 total time=   3.9s
# [CV 4/5; 25/36] START max_depth=8, max_features=1.0, n_estimators=100...........
# [CV 4/5; 25/36] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.948 total time=   3.2s
# [CV 5/5; 25/36] START max_depth=8, max_features=1.0, n_estimators=100...........
# [CV 5/5; 25/36] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.957 total time=   3.2s
# [CV 1/5; 26/36] START max_depth=8, max_features=1.0, n_estimators=200...........
# [CV 1/5; 26/36] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.958 total time=   7.0s
# [CV 2/5; 26/36] START max_depth=8, max_features=1.0, n_estimators=200...........
# [CV 2/5; 26/36] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.954 total time=   6.3s
# [CV 3/5; 26/36] START max_depth=8, max_features=1.0, n_estimators=200...........
# [CV 3/5; 26/36] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.961 total time=   7.1s
# [CV 4/5; 26/36] START max_depth=8, max_features=1.0, n_estimators=200...........
# [CV 4/5; 26/36] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.947 total time=   6.3s
# [CV 5/5; 26/36] START max_depth=8, max_features=1.0, n_estimators=200...........
# [CV 5/5; 26/36] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.959 total time=   7.0s
# [CV 1/5; 27/36] START max_depth=8, max_features=1.0, n_estimators=250...........
# [CV 1/5; 27/36] END max_depth=8, max_features=1.0, n_estimators=250;, score=0.955 total time=   8.2s
# [CV 2/5; 27/36] START max_depth=8, max_features=1.0, n_estimators=250...........
# [CV 2/5; 27/36] END max_depth=8, max_features=1.0, n_estimators=250;, score=0.957 total time=   8.3s
# [CV 3/5; 27/36] START max_depth=8, max_features=1.0, n_estimators=250...........
# [CV 3/5; 27/36] END max_depth=8, max_features=1.0, n_estimators=250;, score=0.967 total time=   8.6s
# [CV 4/5; 27/36] START max_depth=8, max_features=1.0, n_estimators=250...........
# [CV 4/5; 27/36] END max_depth=8, max_features=1.0, n_estimators=250;, score=0.952 total time=   8.0s
# [CV 5/5; 27/36] START max_depth=8, max_features=1.0, n_estimators=250...........
# [CV 5/5; 27/36] END max_depth=8, max_features=1.0, n_estimators=250;, score=0.955 total time=   8.4s
# [CV 1/5; 28/36] START max_depth=10, max_features=0.25, n_estimators=100.........
# [CV 1/5; 28/36] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.955 total time=   1.5s
# [CV 2/5; 28/36] START max_depth=10, max_features=0.25, n_estimators=100.........
# [CV 2/5; 28/36] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.951 total time=   1.5s
# [CV 3/5; 28/36] START max_depth=10, max_features=0.25, n_estimators=100.........
# [CV 3/5; 28/36] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.963 total time=   1.9s
# [CV 4/5; 28/36] START max_depth=10, max_features=0.25, n_estimators=100.........
# [CV 4/5; 28/36] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.943 total time=   1.9s
# [CV 5/5; 28/36] START max_depth=10, max_features=0.25, n_estimators=100.........
# [CV 5/5; 28/36] END max_depth=10, max_features=0.25, n_estimators=100;, score=0.955 total time=   1.5s
# [CV 1/5; 29/36] START max_depth=10, max_features=0.25, n_estimators=200.........
# [CV 1/5; 29/36] END max_depth=10, max_features=0.25, n_estimators=200;, score=0.955 total time=   2.8s
# [CV 2/5; 29/36] START max_depth=10, max_features=0.25, n_estimators=200.........
# [CV 2/5; 29/36] END max_depth=10, max_features=0.25, n_estimators=200;, score=0.958 total time=   2.8s
# [CV 3/5; 29/36] START max_depth=10, max_features=0.25, n_estimators=200.........
# [CV 3/5; 29/36] END max_depth=10, max_features=0.25, n_estimators=200;, score=0.967 total time=   3.0s
# [CV 4/5; 29/36] START max_depth=10, max_features=0.25, n_estimators=200.........
# [CV 4/5; 29/36] END max_depth=10, max_features=0.25, n_estimators=200;, score=0.944 total time=   3.4s
# [CV 5/5; 29/36] START max_depth=10, max_features=0.25, n_estimators=200.........
# [CV 5/5; 29/36] END max_depth=10, max_features=0.25, n_estimators=200;, score=0.961 total time=   2.8s
# [CV 1/5; 30/36] START max_depth=10, max_features=0.25, n_estimators=250.........
# [CV 1/5; 30/36] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.954 total time=   3.5s
# [CV 2/5; 30/36] START max_depth=10, max_features=0.25, n_estimators=250.........
# [CV 2/5; 30/36] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.959 total time=   4.2s
# [CV 3/5; 30/36] START max_depth=10, max_features=0.25, n_estimators=250.........
# [CV 3/5; 30/36] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.967 total time=   3.7s
# [CV 4/5; 30/36] START max_depth=10, max_features=0.25, n_estimators=250.........
# [CV 4/5; 30/36] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.948 total time=   3.4s
# [CV 5/5; 30/36] START max_depth=10, max_features=0.25, n_estimators=250.........
# [CV 5/5; 30/36] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.961 total time=   4.1s
# [CV 1/5; 31/36] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 1/5; 31/36] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.948 total time=   3.5s
# [CV 2/5; 31/36] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 2/5; 31/36] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.951 total time=   2.3s
# [CV 3/5; 31/36] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 3/5; 31/36] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.962 total time=   2.3s
# [CV 4/5; 31/36] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 4/5; 31/36] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.947 total time=   2.3s
# [CV 5/5; 31/36] START max_depth=10, max_features=0.5, n_estimators=100..........
# [CV 5/5; 31/36] END max_depth=10, max_features=0.5, n_estimators=100;, score=0.961 total time=   2.3s
# [CV 1/5; 32/36] START max_depth=10, max_features=0.5, n_estimators=200..........
# [CV 1/5; 32/36] END max_depth=10, max_features=0.5, n_estimators=200;, score=0.954 total time=   5.3s
# [CV 2/5; 32/36] START max_depth=10, max_features=0.5, n_estimators=200..........
# [CV 2/5; 32/36] END max_depth=10, max_features=0.5, n_estimators=200;, score=0.957 total time=   4.5s
# [CV 3/5; 32/36] START max_depth=10, max_features=0.5, n_estimators=200..........
# [CV 3/5; 32/36] END max_depth=10, max_features=0.5, n_estimators=200;, score=0.963 total time=   4.8s
# [CV 4/5; 32/36] START max_depth=10, max_features=0.5, n_estimators=200..........
# [CV 4/5; 32/36] END max_depth=10, max_features=0.5, n_estimators=200;, score=0.948 total time=   4.9s
# [CV 5/5; 32/36] START max_depth=10, max_features=0.5, n_estimators=200..........
# [CV 5/5; 32/36] END max_depth=10, max_features=0.5, n_estimators=200;, score=0.961 total time=   4.5s
# [CV 1/5; 33/36] START max_depth=10, max_features=0.5, n_estimators=250..........
# [CV 1/5; 33/36] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.958 total time=   6.3s
# [CV 2/5; 33/36] START max_depth=10, max_features=0.5, n_estimators=250..........
# [CV 2/5; 33/36] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.959 total time=   5.5s
# [CV 3/5; 33/36] START max_depth=10, max_features=0.5, n_estimators=250..........
# [CV 3/5; 33/36] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.961 total time=   6.4s
# [CV 4/5; 33/36] START max_depth=10, max_features=0.5, n_estimators=250..........
# [CV 4/5; 33/36] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.951 total time=   5.5s
# [CV 5/5; 33/36] START max_depth=10, max_features=0.5, n_estimators=250..........
# [CV 5/5; 33/36] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.961 total time=   6.4s
# [CV 1/5; 34/36] START max_depth=10, max_features=1.0, n_estimators=100..........
# [CV 1/5; 34/36] END max_depth=10, max_features=1.0, n_estimators=100;, score=0.950 total time=   4.0s
# [CV 2/5; 34/36] START max_depth=10, max_features=1.0, n_estimators=100..........
# [CV 2/5; 34/36] END max_depth=10, max_features=1.0, n_estimators=100;, score=0.948 total time=   4.0s
# [CV 3/5; 34/36] START max_depth=10, max_features=1.0, n_estimators=100..........
# [CV 3/5; 34/36] END max_depth=10, max_features=1.0, n_estimators=100;, score=0.959 total time=   4.8s
# [CV 4/5; 34/36] START max_depth=10, max_features=1.0, n_estimators=100..........
# [CV 4/5; 34/36] END max_depth=10, max_features=1.0, n_estimators=100;, score=0.943 total time=   4.0s
# [CV 5/5; 34/36] START max_depth=10, max_features=1.0, n_estimators=100..........
# [CV 5/5; 34/36] END max_depth=10, max_features=1.0, n_estimators=100;, score=0.952 total time=   4.0s
# [CV 1/5; 35/36] START max_depth=10, max_features=1.0, n_estimators=200..........
# [CV 1/5; 35/36] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.952 total time=   8.7s
# [CV 2/5; 35/36] START max_depth=10, max_features=1.0, n_estimators=200..........
# [CV 2/5; 35/36] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.952 total time=   8.7s
# [CV 3/5; 35/36] START max_depth=10, max_features=1.0, n_estimators=200..........
# [CV 3/5; 35/36] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.962 total time=   8.0s
# [CV 4/5; 35/36] START max_depth=10, max_features=1.0, n_estimators=200..........
# [CV 4/5; 35/36] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.948 total time=   8.6s
# [CV 5/5; 35/36] START max_depth=10, max_features=1.0, n_estimators=200..........
# [CV 5/5; 35/36] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.954 total time=   8.6s
# [CV 1/5; 36/36] START max_depth=10, max_features=1.0, n_estimators=250..........
# [CV 1/5; 36/36] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.958 total time=  10.1s
# [CV 2/5; 36/36] START max_depth=10, max_features=1.0, n_estimators=250..........
# [CV 2/5; 36/36] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.959 total time=  10.4s
# [CV 3/5; 36/36] START max_depth=10, max_features=1.0, n_estimators=250..........
# [CV 3/5; 36/36] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.962 total time=  10.7s
# [CV 4/5; 36/36] START max_depth=10, max_features=1.0, n_estimators=250..........
# [CV 4/5; 36/36] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.951 total time=  10.5s
# [CV 5/5; 36/36] START max_depth=10, max_features=1.0, n_estimators=250..........
# [CV 5/5; 36/36] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.955 total time=  10.6s
# Precisión: 95.2% con {'max_depth': 8, 'max_features': 0.25, 'n_estimators': 250}

# %% [markdown]
# ### Acelerar la búsqueda de parámetros: RandomizedSearch
#
# Un problema recurrente que tenemos en estos experimentos es el coste temporal de encontrar los mejores parámetros mediante GridSearch. Una alternativa que reduce dicho coste temporal es el [RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#
# **Ejercicio** Implementa la misma búsqueda de valores que has realizado con GridSearch pero ahora con RandomizedSearch con n_iter=10 para limitar el número de pruebas a 10.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier

clf=GradientBoostingClassifier()

G = {"max_depth" : [4,6,8,10], "max_features" : [0.25, 0.5, 1.0], "n_estimators": [100,200,250]}


GS = RandomizedSearchCV(clf,G, scoring='accuracy', n_iter = 10, refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START max_depth=10, max_features=0.5, n_estimators=250...........
# [CV 1/5; 1/10] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.955 total time=   5.6s
# [CV 2/5; 1/10] START max_depth=10, max_features=0.5, n_estimators=250...........
# [CV 2/5; 1/10] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.957 total time=   6.5s
# [CV 3/5; 1/10] START max_depth=10, max_features=0.5, n_estimators=250...........
# [CV 3/5; 1/10] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.963 total time=   5.6s
# [CV 4/5; 1/10] START max_depth=10, max_features=0.5, n_estimators=250...........
# [CV 4/5; 1/10] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.950 total time=   6.3s
# [CV 5/5; 1/10] START max_depth=10, max_features=0.5, n_estimators=250...........
# [CV 5/5; 1/10] END max_depth=10, max_features=0.5, n_estimators=250;, score=0.957 total time=   5.5s
# [CV 1/5; 2/10] START max_depth=10, max_features=1.0, n_estimators=250...........
# [CV 1/5; 2/10] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.952 total time=  10.8s
# [CV 2/5; 2/10] START max_depth=10, max_features=1.0, n_estimators=250...........
# [CV 2/5; 2/10] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.958 total time=  10.8s
# [CV 3/5; 2/10] START max_depth=10, max_features=1.0, n_estimators=250...........
# [CV 3/5; 2/10] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.958 total time=  10.8s
# [CV 4/5; 2/10] START max_depth=10, max_features=1.0, n_estimators=250...........
# [CV 4/5; 2/10] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.950 total time=  10.7s
# [CV 5/5; 2/10] START max_depth=10, max_features=1.0, n_estimators=250...........
# [CV 5/5; 2/10] END max_depth=10, max_features=1.0, n_estimators=250;, score=0.948 total time=  10.2s
# [CV 1/5; 3/10] START max_depth=6, max_features=0.25, n_estimators=100...........
# [CV 1/5; 3/10] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.944 total time=   0.8s
# [CV 2/5; 3/10] START max_depth=6, max_features=0.25, n_estimators=100...........
# [CV 2/5; 3/10] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.954 total time=   1.1s
# [CV 3/5; 3/10] START max_depth=6, max_features=0.25, n_estimators=100...........
# [CV 3/5; 3/10] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.957 total time=   1.1s
# [CV 4/5; 3/10] START max_depth=6, max_features=0.25, n_estimators=100...........
# [CV 4/5; 3/10] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.948 total time=   0.9s
# [CV 5/5; 3/10] START max_depth=6, max_features=0.25, n_estimators=100...........
# [CV 5/5; 3/10] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.961 total time=   0.8s
# [CV 1/5; 4/10] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 1/5; 4/10] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.952 total time=   1.7s
# [CV 2/5; 4/10] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 2/5; 4/10] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.947 total time=   1.8s
# [CV 3/5; 4/10] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 3/5; 4/10] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.963 total time=   1.9s
# [CV 4/5; 4/10] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 4/5; 4/10] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.944 total time=   1.7s
# [CV 5/5; 4/10] START max_depth=8, max_features=0.5, n_estimators=100............
# [CV 5/5; 4/10] END max_depth=8, max_features=0.5, n_estimators=100;, score=0.957 total time=   1.9s
# [CV 1/5; 5/10] START max_depth=6, max_features=0.25, n_estimators=200...........
# [CV 1/5; 5/10] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.948 total time=   2.6s
# [CV 2/5; 5/10] START max_depth=6, max_features=0.25, n_estimators=200...........
# [CV 2/5; 5/10] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.959 total time=   2.3s
# [CV 3/5; 5/10] START max_depth=6, max_features=0.25, n_estimators=200...........
# [CV 3/5; 5/10] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.969 total time=   1.5s
# [CV 4/5; 5/10] START max_depth=6, max_features=0.25, n_estimators=200...........
# [CV 4/5; 5/10] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.950 total time=   1.5s
# [CV 5/5; 5/10] START max_depth=6, max_features=0.25, n_estimators=200...........
# [CV 5/5; 5/10] END max_depth=6, max_features=0.25, n_estimators=200;, score=0.959 total time=   1.5s
# [CV 1/5; 6/10] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 1/5; 6/10] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.955 total time=   1.0s
# [CV 2/5; 6/10] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 2/5; 6/10] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.952 total time=   1.0s
# [CV 3/5; 6/10] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 3/5; 6/10] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.965 total time=   1.0s
# [CV 4/5; 6/10] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 4/5; 6/10] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.942 total time=   1.0s
# [CV 5/5; 6/10] START max_depth=4, max_features=0.25, n_estimators=200...........
# [CV 5/5; 6/10] END max_depth=4, max_features=0.25, n_estimators=200;, score=0.963 total time=   1.0s
# [CV 1/5; 7/10] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 1/5; 7/10] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.954 total time=   4.0s
# [CV 2/5; 7/10] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 2/5; 7/10] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.947 total time=   3.4s
# [CV 3/5; 7/10] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 3/5; 7/10] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.957 total time=   3.5s
# [CV 4/5; 7/10] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 4/5; 7/10] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.947 total time=   3.9s
# [CV 5/5; 7/10] START max_depth=4, max_features=1.0, n_estimators=200............
# [CV 5/5; 7/10] END max_depth=4, max_features=1.0, n_estimators=200;, score=0.958 total time=   3.5s
# [CV 1/5; 8/10] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 1/5; 8/10] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.952 total time=   3.2s
# [CV 2/5; 8/10] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 2/5; 8/10] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.951 total time=   3.2s
# [CV 3/5; 8/10] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 3/5; 8/10] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.962 total time=   3.9s
# [CV 4/5; 8/10] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 4/5; 8/10] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.944 total time=   3.2s
# [CV 5/5; 8/10] START max_depth=8, max_features=1.0, n_estimators=100............
# [CV 5/5; 8/10] END max_depth=8, max_features=1.0, n_estimators=100;, score=0.950 total time=   3.1s
# [CV 1/5; 9/10] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 1/5; 9/10] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.943 total time=   0.5s
# [CV 2/5; 9/10] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 2/5; 9/10] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.947 total time=   0.5s
# [CV 3/5; 9/10] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 3/5; 9/10] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.959 total time=   0.5s
# [CV 4/5; 9/10] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 4/5; 9/10] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.943 total time=   0.5s
# [CV 5/5; 9/10] START max_depth=4, max_features=0.25, n_estimators=100...........
# [CV 5/5; 9/10] END max_depth=4, max_features=0.25, n_estimators=100;, score=0.957 total time=   0.5s
# [CV 1/5; 10/10] START max_depth=4, max_features=1.0, n_estimators=250...........
# [CV 1/5; 10/10] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.955 total time=   4.8s
# [CV 2/5; 10/10] START max_depth=4, max_features=1.0, n_estimators=250...........
# [CV 2/5; 10/10] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.950 total time=   4.0s
# [CV 3/5; 10/10] START max_depth=4, max_features=1.0, n_estimators=250...........
# [CV 3/5; 10/10] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.959 total time=   4.0s
# [CV 4/5; 10/10] START max_depth=4, max_features=1.0, n_estimators=250...........
# [CV 4/5; 10/10] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.947 total time=   4.8s
# [CV 5/5; 10/10] START max_depth=4, max_features=1.0, n_estimators=250...........
# [CV 5/5; 10/10] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.959 total time=   4.0s
# Precisión: 95.5% con {'n_estimators': 200, 'max_features': 0.25, 'max_depth': 6}

# %% [markdown]
# ### Mejorar la búsqueda de parámetros: BayesianOptimization
#
# Optimización Bayesiana es una técnica avanzada de búsqueda de parámetros. Para poder emplearla hay que instalar la librería scikit-optimize. El uso de dicha técnica es similar a las ya empleadas con la diferencia que el rango de los parámetros hay que definirlos teniendo en cuenta además el tipo de los mismos: real, entero o categórico. Además los valores a probar no se listan explícitamente si no que se especifica un rango dentro del cual el algoritmo escogerá los valores.
#
# La ejecución puede resultar más lenta pero se pueden explorar más parámetros, de hecho se especifica un intervalo en lugar de valores concretos.

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.1-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.4.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-24.4.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (24.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.5.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-24.4.0 scikit-optimize-0.10.1

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
BS = BayesSearchCV(GradientBoostingClassifier(), G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=250.............
# [CV 1/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.955 total time=   4.5s
# [CV 2/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=250.............
# [CV 2/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.951 total time=   4.7s
# [CV 3/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=250.............
# [CV 3/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.961 total time=   5.0s
# [CV 4/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=250.............
# [CV 4/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.944 total time=   5.4s
# [CV 5/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=250.............
# [CV 5/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=250;, score=0.958 total time=   5.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=250............
# [CV 1/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.955 total time=   2.7s
# [CV 2/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=250............
# [CV 2/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.957 total time=   6.4s
# [CV 3/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=250............
# [CV 3/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.963 total time=   2.6s
# [CV 4/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=250............
# [CV 4/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.947 total time=   1.9s
# [CV 5/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=250............
# [CV 5/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=250;, score=0.957 total time=   1.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 1/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.952 total time=   4.4s
# [CV 2/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 2/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.962 total time=   3.6s
# [CV 3/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 3/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.966 total time=   3.6s
# [CV 4/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 4/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.948 total time=   3.8s
# [CV 5/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 5/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.961 total time=   4.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=200.............
# [CV 1/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.958 total time=   6.4s
# [CV 2/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=200.............
# [CV 2/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.952 total time=   8.4s
# [CV 3/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=200.............
# [CV 3/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.963 total time=   6.8s
# [CV 4/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=200.............
# [CV 4/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.950 total time=   8.2s
# [CV 5/5; 1/1] START max_depth=8, max_features=1.0, n_estimators=200.............
# [CV 5/5; 1/1] END max_depth=8, max_features=1.0, n_estimators=200;, score=0.955 total time=   8.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=100.............
# [CV 1/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.948 total time=   1.6s
# [CV 2/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=100.............
# [CV 2/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.944 total time=   1.6s
# [CV 3/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=100.............
# [CV 3/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.955 total time=   1.6s
# [CV 4/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=100.............
# [CV 4/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.942 total time=   1.6s
# [CV 5/5; 1/1] START max_depth=4, max_features=1.0, n_estimators=100.............
# [CV 5/5; 1/1] END max_depth=4, max_features=1.0, n_estimators=100;, score=0.952 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=250.............
# [CV 1/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.951 total time=   2.8s
# [CV 2/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=250.............
# [CV 2/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.955 total time=   2.4s
# [CV 3/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=250.............
# [CV 3/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.957 total time=   2.2s
# [CV 4/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=250.............
# [CV 4/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.946 total time=   2.2s
# [CV 5/5; 1/1] START max_depth=4, max_features=0.5, n_estimators=250.............
# [CV 5/5; 1/1] END max_depth=4, max_features=0.5, n_estimators=250;, score=0.959 total time=   2.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=100............
# [CV 1/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.957 total time=   0.8s
# [CV 2/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=100............
# [CV 2/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.957 total time=   0.8s
# [CV 3/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=100............
# [CV 3/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.963 total time=   1.2s
# [CV 4/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=100............
# [CV 4/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.948 total time=   2.7s
# [CV 5/5; 1/1] START max_depth=6, max_features=0.25, n_estimators=100............
# [CV 5/5; 1/1] END max_depth=6, max_features=0.25, n_estimators=100;, score=0.955 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 1/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.951 total time=   3.3s
# [CV 2/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 2/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.951 total time=   3.7s
# [CV 3/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 3/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.962 total time=   3.1s
# [CV 4/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 4/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.946 total time=   4.9s
# [CV 5/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 5/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.955 total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 1/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.952 total time=   3.6s
# [CV 2/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 2/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.947 total time=   4.4s
# [CV 3/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 3/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.954 total time=   2.5s
# [CV 4/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 4/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.944 total time=   2.5s
# [CV 5/5; 1/1] START max_depth=6, max_features=1.0, n_estimators=100.............
# [CV 5/5; 1/1] END max_depth=6, max_features=1.0, n_estimators=100;, score=0.955 total time=   3.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 1/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.957 total time=   5.8s
# [CV 2/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 2/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.962 total time=   3.5s
# [CV 3/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 3/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.963 total time=   4.1s
# [CV 4/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 4/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.950 total time=   4.9s
# [CV 5/5; 1/1] START max_depth=10, max_features=0.25, n_estimators=250...........
# [CV 5/5; 1/1] END max_depth=10, max_features=0.25, n_estimators=250;, score=0.962 total time=   3.5s
# Precisión: 95.8% con OrderedDict([('max_depth', 10), ('max_features', 0.25), ('n_estimators', 250)])

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

G = {"max_depth" : Integer(2,10), "max_features" : [0.1,1.0], "n_estimators": Integer(50,200)}

BS = BayesSearchCV(GradientBoostingClassifier(), G, scoring='accuracy', n_iter=25, refit=True, cv=5, verbose=10)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# /usr/local/lib/python3.10/dist-packages/skopt/space/space.py:110: UserWarning: Dimension [0.1, 1.0] was inferred to Real(low=0.1, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.1, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/skopt/space/space.py:110: UserWarning: Dimension [0.1, 1.0] was inferred to Real(low=0.1, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.1, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/skopt/space/space.py:110: UserWarning: Dimension [0.1, 1.0] was inferred to Real(low=0.1, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.1, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=0.18693114344560607, n_estimators=112
# [CV 1/5; 1/1] END max_depth=8, max_features=0.18693114344560607, n_estimators=112;, score=0.955 total time=   1.0s
# [CV 2/5; 1/1] START max_depth=8, max_features=0.18693114344560607, n_estimators=112
# [CV 2/5; 1/1] END max_depth=8, max_features=0.18693114344560607, n_estimators=112;, score=0.950 total time=   1.0s
# [CV 3/5; 1/1] START max_depth=8, max_features=0.18693114344560607, n_estimators=112
# [CV 3/5; 1/1] END max_depth=8, max_features=0.18693114344560607, n_estimators=112;, score=0.969 total time=   1.0s
# [CV 4/5; 1/1] START max_depth=8, max_features=0.18693114344560607, n_estimators=112
# [CV 4/5; 1/1] END max_depth=8, max_features=0.18693114344560607, n_estimators=112;, score=0.946 total time=   0.9s
# [CV 5/5; 1/1] START max_depth=8, max_features=0.18693114344560607, n_estimators=112
# [CV 5/5; 1/1] END max_depth=8, max_features=0.18693114344560607, n_estimators=112;, score=0.961 total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=0.11336539406373448, n_estimators=128
# [CV 1/5; 1/1] END max_depth=6, max_features=0.11336539406373448, n_estimators=128;, score=0.950 total time=   0.6s
# [CV 2/5; 1/1] START max_depth=6, max_features=0.11336539406373448, n_estimators=128
# [CV 2/5; 1/1] END max_depth=6, max_features=0.11336539406373448, n_estimators=128;, score=0.957 total time=   0.6s
# [CV 3/5; 1/1] START max_depth=6, max_features=0.11336539406373448, n_estimators=128
# [CV 3/5; 1/1] END max_depth=6, max_features=0.11336539406373448, n_estimators=128;, score=0.970 total time=   0.6s
# [CV 4/5; 1/1] START max_depth=6, max_features=0.11336539406373448, n_estimators=128
# [CV 4/5; 1/1] END max_depth=6, max_features=0.11336539406373448, n_estimators=128;, score=0.950 total time=   0.6s
# [CV 5/5; 1/1] START max_depth=6, max_features=0.11336539406373448, n_estimators=128
# [CV 5/5; 1/1] END max_depth=6, max_features=0.11336539406373448, n_estimators=128;, score=0.959 total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=7, max_features=0.5870114183342056, n_estimators=108
# [CV 1/5; 1/1] END max_depth=7, max_features=0.5870114183342056, n_estimators=108;, score=0.950 total time=   3.5s
# [CV 2/5; 1/1] START max_depth=7, max_features=0.5870114183342056, n_estimators=108
# [CV 2/5; 1/1] END max_depth=7, max_features=0.5870114183342056, n_estimators=108;, score=0.951 total time=   2.1s
# [CV 3/5; 1/1] START max_depth=7, max_features=0.5870114183342056, n_estimators=108
# [CV 3/5; 1/1] END max_depth=7, max_features=0.5870114183342056, n_estimators=108;, score=0.961 total time=   1.9s
# [CV 4/5; 1/1] START max_depth=7, max_features=0.5870114183342056, n_estimators=108
# [CV 4/5; 1/1] END max_depth=7, max_features=0.5870114183342056, n_estimators=108;, score=0.946 total time=   1.9s
# [CV 5/5; 1/1] START max_depth=7, max_features=0.5870114183342056, n_estimators=108
# [CV 5/5; 1/1] END max_depth=7, max_features=0.5870114183342056, n_estimators=108;, score=0.962 total time=   1.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=0.9861290792455584, n_estimators=56
# [CV 1/5; 1/1] END max_depth=8, max_features=0.9861290792455584, n_estimators=56;, score=0.952 total time=   1.8s
# [CV 2/5; 1/1] START max_depth=8, max_features=0.9861290792455584, n_estimators=56
# [CV 2/5; 1/1] END max_depth=8, max_features=0.9861290792455584, n_estimators=56;, score=0.942 total time=   2.4s
# [CV 3/5; 1/1] START max_depth=8, max_features=0.9861290792455584, n_estimators=56
# [CV 3/5; 1/1] END max_depth=8, max_features=0.9861290792455584, n_estimators=56;, score=0.958 total time=   2.0s
# [CV 4/5; 1/1] START max_depth=8, max_features=0.9861290792455584, n_estimators=56
# [CV 4/5; 1/1] END max_depth=8, max_features=0.9861290792455584, n_estimators=56;, score=0.942 total time=   1.8s
# [CV 5/5; 1/1] START max_depth=8, max_features=0.9861290792455584, n_estimators=56
# [CV 5/5; 1/1] END max_depth=8, max_features=0.9861290792455584, n_estimators=56;, score=0.951 total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=3, max_features=0.6493874085962883, n_estimators=70
# [CV 1/5; 1/1] END max_depth=3, max_features=0.6493874085962883, n_estimators=70;, score=0.943 total time=   0.6s
# [CV 2/5; 1/1] START max_depth=3, max_features=0.6493874085962883, n_estimators=70
# [CV 2/5; 1/1] END max_depth=3, max_features=0.6493874085962883, n_estimators=70;, score=0.935 total time=   0.6s
# [CV 3/5; 1/1] START max_depth=3, max_features=0.6493874085962883, n_estimators=70
# [CV 3/5; 1/1] END max_depth=3, max_features=0.6493874085962883, n_estimators=70;, score=0.957 total time=   0.6s
# [CV 4/5; 1/1] START max_depth=3, max_features=0.6493874085962883, n_estimators=70
# [CV 4/5; 1/1] END max_depth=3, max_features=0.6493874085962883, n_estimators=70;, score=0.932 total time=   0.6s
# [CV 5/5; 1/1] START max_depth=3, max_features=0.6493874085962883, n_estimators=70
# [CV 5/5; 1/1] END max_depth=3, max_features=0.6493874085962883, n_estimators=70;, score=0.950 total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=0.5804146121873127, n_estimators=100
# [CV 1/5; 1/1] END max_depth=6, max_features=0.5804146121873127, n_estimators=100;, score=0.951 total time=   1.5s
# [CV 2/5; 1/1] START max_depth=6, max_features=0.5804146121873127, n_estimators=100
# [CV 2/5; 1/1] END max_depth=6, max_features=0.5804146121873127, n_estimators=100;, score=0.952 total time=   1.8s
# [CV 3/5; 1/1] START max_depth=6, max_features=0.5804146121873127, n_estimators=100
# [CV 3/5; 1/1] END max_depth=6, max_features=0.5804146121873127, n_estimators=100;, score=0.951 total time=   2.3s
# [CV 4/5; 1/1] START max_depth=6, max_features=0.5804146121873127, n_estimators=100
# [CV 4/5; 1/1] END max_depth=6, max_features=0.5804146121873127, n_estimators=100;, score=0.944 total time=   1.5s
# [CV 5/5; 1/1] START max_depth=6, max_features=0.5804146121873127, n_estimators=100
# [CV 5/5; 1/1] END max_depth=6, max_features=0.5804146121873127, n_estimators=100;, score=0.958 total time=   1.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=0.6785362972124093, n_estimators=112
# [CV 1/5; 1/1] END max_depth=8, max_features=0.6785362972124093, n_estimators=112;, score=0.954 total time=   2.5s
# [CV 2/5; 1/1] START max_depth=8, max_features=0.6785362972124093, n_estimators=112
# [CV 2/5; 1/1] END max_depth=8, max_features=0.6785362972124093, n_estimators=112;, score=0.952 total time=   2.5s
# [CV 3/5; 1/1] START max_depth=8, max_features=0.6785362972124093, n_estimators=112
# [CV 3/5; 1/1] END max_depth=8, max_features=0.6785362972124093, n_estimators=112;, score=0.958 total time=   2.9s
# [CV 4/5; 1/1] START max_depth=8, max_features=0.6785362972124093, n_estimators=112
# [CV 4/5; 1/1] END max_depth=8, max_features=0.6785362972124093, n_estimators=112;, score=0.947 total time=   3.0s
# [CV 5/5; 1/1] START max_depth=8, max_features=0.6785362972124093, n_estimators=112
# [CV 5/5; 1/1] END max_depth=8, max_features=0.6785362972124093, n_estimators=112;, score=0.958 total time=   2.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=0.8361205873595392, n_estimators=93
# [CV 1/5; 1/1] END max_depth=8, max_features=0.8361205873595392, n_estimators=93;, score=0.950 total time=   2.5s
# [CV 2/5; 1/1] START max_depth=8, max_features=0.8361205873595392, n_estimators=93
# [CV 2/5; 1/1] END max_depth=8, max_features=0.8361205873595392, n_estimators=93;, score=0.947 total time=   2.5s
# [CV 3/5; 1/1] START max_depth=8, max_features=0.8361205873595392, n_estimators=93
# [CV 3/5; 1/1] END max_depth=8, max_features=0.8361205873595392, n_estimators=93;, score=0.958 total time=   3.1s
# [CV 4/5; 1/1] START max_depth=8, max_features=0.8361205873595392, n_estimators=93
# [CV 4/5; 1/1] END max_depth=8, max_features=0.8361205873595392, n_estimators=93;, score=0.938 total time=   2.7s
# [CV 5/5; 1/1] START max_depth=8, max_features=0.8361205873595392, n_estimators=93
# [CV 5/5; 1/1] END max_depth=8, max_features=0.8361205873595392, n_estimators=93;, score=0.959 total time=   2.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=0.5837053527033941, n_estimators=156
# [CV 1/5; 1/1] END max_depth=4, max_features=0.5837053527033941, n_estimators=156;, score=0.947 total time=   1.6s
# [CV 2/5; 1/1] START max_depth=4, max_features=0.5837053527033941, n_estimators=156
# [CV 2/5; 1/1] END max_depth=4, max_features=0.5837053527033941, n_estimators=156;, score=0.952 total time=   1.6s
# [CV 3/5; 1/1] START max_depth=4, max_features=0.5837053527033941, n_estimators=156
# [CV 3/5; 1/1] END max_depth=4, max_features=0.5837053527033941, n_estimators=156;, score=0.951 total time=   1.6s
# [CV 4/5; 1/1] START max_depth=4, max_features=0.5837053527033941, n_estimators=156
# [CV 4/5; 1/1] END max_depth=4, max_features=0.5837053527033941, n_estimators=156;, score=0.942 total time=   1.8s
# [CV 5/5; 1/1] START max_depth=4, max_features=0.5837053527033941, n_estimators=156
# [CV 5/5; 1/1] END max_depth=4, max_features=0.5837053527033941, n_estimators=156;, score=0.961 total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=0.15573070589302085, n_estimators=140
# [CV 1/5; 1/1] END max_depth=4, max_features=0.15573070589302085, n_estimators=140;, score=0.947 total time=   0.5s
# [CV 2/5; 1/1] START max_depth=4, max_features=0.15573070589302085, n_estimators=140
# [CV 2/5; 1/1] END max_depth=4, max_features=0.15573070589302085, n_estimators=140;, score=0.951 total time=   0.5s
# [CV 3/5; 1/1] START max_depth=4, max_features=0.15573070589302085, n_estimators=140
# [CV 3/5; 1/1] END max_depth=4, max_features=0.15573070589302085, n_estimators=140;, score=0.962 total time=   0.5s
# [CV 4/5; 1/1] START max_depth=4, max_features=0.15573070589302085, n_estimators=140
# [CV 4/5; 1/1] END max_depth=4, max_features=0.15573070589302085, n_estimators=140;, score=0.947 total time=   0.5s
# [CV 5/5; 1/1] START max_depth=4, max_features=0.15573070589302085, n_estimators=140
# [CV 5/5; 1/1] END max_depth=4, max_features=0.15573070589302085, n_estimators=140;, score=0.957 total time=   0.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, max_features=0.10493619985099742, n_estimators=199
# [CV 1/5; 1/1] END max_depth=10, max_features=0.10493619985099742, n_estimators=199;, score=0.959 total time=   1.8s
# [CV 2/5; 1/1] START max_depth=10, max_features=0.10493619985099742, n_estimators=199
# [CV 2/5; 1/1] END max_depth=10, max_features=0.10493619985099742, n_estimators=199;, score=0.966 total time=   1.8s
# [CV 3/5; 1/1] START max_depth=10, max_features=0.10493619985099742, n_estimators=199
# [CV 3/5; 1/1] END max_depth=10, max_features=0.10493619985099742, n_estimators=199;, score=0.971 total time=   1.8s
# [CV 4/5; 1/1] START max_depth=10, max_features=0.10493619985099742, n_estimators=199
# [CV 4/5; 1/1] END max_depth=10, max_features=0.10493619985099742, n_estimators=199;, score=0.947 total time=   2.3s
# [CV 5/5; 1/1] START max_depth=10, max_features=0.10493619985099742, n_estimators=199
# [CV 5/5; 1/1] END max_depth=10, max_features=0.10493619985099742, n_estimators=199;, score=0.959 total time=   2.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=200............
# [CV 1/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.954 total time=   8.0s
# [CV 2/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=200............
# [CV 2/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.950 total time=   8.9s
# [CV 3/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=200............
# [CV 3/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.955 total time=   8.8s
# [CV 4/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=200............
# [CV 4/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.951 total time=   9.1s
# [CV 5/5; 1/1] START max_depth=10, max_features=1.0, n_estimators=200............
# [CV 5/5; 1/1] END max_depth=10, max_features=1.0, n_estimators=200;, score=0.952 total time=   9.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, max_features=0.1227179191385804, n_estimators=50
# [CV 1/5; 1/1] END max_depth=10, max_features=0.1227179191385804, n_estimators=50;, score=0.950 total time=   0.6s
# [CV 2/5; 1/1] START max_depth=10, max_features=0.1227179191385804, n_estimators=50
# [CV 2/5; 1/1] END max_depth=10, max_features=0.1227179191385804, n_estimators=50;, score=0.951 total time=   0.5s
# [CV 3/5; 1/1] START max_depth=10, max_features=0.1227179191385804, n_estimators=50
# [CV 3/5; 1/1] END max_depth=10, max_features=0.1227179191385804, n_estimators=50;, score=0.955 total time=   0.5s
# [CV 4/5; 1/1] START max_depth=10, max_features=0.1227179191385804, n_estimators=50
# [CV 4/5; 1/1] END max_depth=10, max_features=0.1227179191385804, n_estimators=50;, score=0.946 total time=   0.6s
# [CV 5/5; 1/1] START max_depth=10, max_features=0.1227179191385804, n_estimators=50
# [CV 5/5; 1/1] END max_depth=10, max_features=0.1227179191385804, n_estimators=50;, score=0.954 total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=7, max_features=0.1, n_estimators=200.............
# [CV 1/5; 1/1] END max_depth=7, max_features=0.1, n_estimators=200;, score=0.954 total time=   1.1s
# [CV 2/5; 1/1] START max_depth=7, max_features=0.1, n_estimators=200.............
# [CV 2/5; 1/1] END max_depth=7, max_features=0.1, n_estimators=200;, score=0.955 total time=   1.0s
# [CV 3/5; 1/1] START max_depth=7, max_features=0.1, n_estimators=200.............
# [CV 3/5; 1/1] END max_depth=7, max_features=0.1, n_estimators=200;, score=0.977 total time=   1.0s
# [CV 4/5; 1/1] START max_depth=7, max_features=0.1, n_estimators=200.............
# [CV 4/5; 1/1] END max_depth=7, max_features=0.1, n_estimators=200;, score=0.954 total time=   1.0s
# [CV 5/5; 1/1] START max_depth=7, max_features=0.1, n_estimators=200.............
# [CV 5/5; 1/1] END max_depth=7, max_features=0.1, n_estimators=200;, score=0.959 total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=9, max_features=0.49464532641741177, n_estimators=200
# [CV 1/5; 1/1] END max_depth=9, max_features=0.49464532641741177, n_estimators=200;, score=0.955 total time=   4.0s
# [CV 2/5; 1/1] START max_depth=9, max_features=0.49464532641741177, n_estimators=200
# [CV 2/5; 1/1] END max_depth=9, max_features=0.49464532641741177, n_estimators=200;, score=0.957 total time=   4.8s
# [CV 3/5; 1/1] START max_depth=9, max_features=0.49464532641741177, n_estimators=200
# [CV 3/5; 1/1] END max_depth=9, max_features=0.49464532641741177, n_estimators=200;, score=0.961 total time=   4.0s
# [CV 4/5; 1/1] START max_depth=9, max_features=0.49464532641741177, n_estimators=200
# [CV 4/5; 1/1] END max_depth=9, max_features=0.49464532641741177, n_estimators=200;, score=0.947 total time=   3.9s
# [CV 5/5; 1/1] START max_depth=9, max_features=0.49464532641741177, n_estimators=200
# [CV 5/5; 1/1] END max_depth=9, max_features=0.49464532641741177, n_estimators=200;, score=0.959 total time=   4.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=2, max_features=0.13357111431724, n_estimators=198
# [CV 1/5; 1/1] END max_depth=2, max_features=0.13357111431724, n_estimators=198;, score=0.944 total time=   0.4s
# [CV 2/5; 1/1] START max_depth=2, max_features=0.13357111431724, n_estimators=198
# [CV 2/5; 1/1] END max_depth=2, max_features=0.13357111431724, n_estimators=198;, score=0.935 total time=   0.4s
# [CV 3/5; 1/1] START max_depth=2, max_features=0.13357111431724, n_estimators=198
# [CV 3/5; 1/1] END max_depth=2, max_features=0.13357111431724, n_estimators=198;, score=0.961 total time=   0.4s
# [CV 4/5; 1/1] START max_depth=2, max_features=0.13357111431724, n_estimators=198
# [CV 4/5; 1/1] END max_depth=2, max_features=0.13357111431724, n_estimators=198;, score=0.944 total time=   0.4s
# [CV 5/5; 1/1] START max_depth=2, max_features=0.13357111431724, n_estimators=198
# [CV 5/5; 1/1] END max_depth=2, max_features=0.13357111431724, n_estimators=198;, score=0.950 total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=0.9903831381391289, n_estimators=198
# [CV 1/5; 1/1] END max_depth=6, max_features=0.9903831381391289, n_estimators=198;, score=0.951 total time=   4.7s
# [CV 2/5; 1/1] START max_depth=6, max_features=0.9903831381391289, n_estimators=198
# [CV 2/5; 1/1] END max_depth=6, max_features=0.9903831381391289, n_estimators=198;, score=0.955 total time=   5.5s
# [CV 3/5; 1/1] START max_depth=6, max_features=0.9903831381391289, n_estimators=198
# [CV 3/5; 1/1] END max_depth=6, max_features=0.9903831381391289, n_estimators=198;, score=0.966 total time=   4.6s
# [CV 4/5; 1/1] START max_depth=6, max_features=0.9903831381391289, n_estimators=198
# [CV 4/5; 1/1] END max_depth=6, max_features=0.9903831381391289, n_estimators=198;, score=0.951 total time=   5.2s
# [CV 5/5; 1/1] START max_depth=6, max_features=0.9903831381391289, n_estimators=198
# [CV 5/5; 1/1] END max_depth=6, max_features=0.9903831381391289, n_estimators=198;, score=0.962 total time=   4.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=200.............
# [CV 1/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=200;, score=0.952 total time=   1.2s
# [CV 2/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=200.............
# [CV 2/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=200;, score=0.966 total time=   1.2s
# [CV 3/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=200.............
# [CV 3/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=200;, score=0.970 total time=   1.2s
# [CV 4/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=200.............
# [CV 4/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=200;, score=0.954 total time=   1.2s
# [CV 5/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=200.............
# [CV 5/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=200;, score=0.958 total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=2, max_features=0.9890422423620264, n_estimators=194
# [CV 1/5; 1/1] END max_depth=2, max_features=0.9890422423620264, n_estimators=194;, score=0.946 total time=   1.7s
# [CV 2/5; 1/1] START max_depth=2, max_features=0.9890422423620264, n_estimators=194
# [CV 2/5; 1/1] END max_depth=2, max_features=0.9890422423620264, n_estimators=194;, score=0.943 total time=   1.6s
# [CV 3/5; 1/1] START max_depth=2, max_features=0.9890422423620264, n_estimators=194
# [CV 3/5; 1/1] END max_depth=2, max_features=0.9890422423620264, n_estimators=194;, score=0.952 total time=   1.6s
# [CV 4/5; 1/1] START max_depth=2, max_features=0.9890422423620264, n_estimators=194
# [CV 4/5; 1/1] END max_depth=2, max_features=0.9890422423620264, n_estimators=194;, score=0.938 total time=   1.6s
# [CV 5/5; 1/1] START max_depth=2, max_features=0.9890422423620264, n_estimators=194
# [CV 5/5; 1/1] END max_depth=2, max_features=0.9890422423620264, n_estimators=194;, score=0.954 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=0.14031339755327152, n_estimators=52
# [CV 1/5; 1/1] END max_depth=6, max_features=0.14031339755327152, n_estimators=52;, score=0.946 total time=   0.3s
# [CV 2/5; 1/1] START max_depth=6, max_features=0.14031339755327152, n_estimators=52
# [CV 2/5; 1/1] END max_depth=6, max_features=0.14031339755327152, n_estimators=52;, score=0.938 total time=   0.3s
# [CV 3/5; 1/1] START max_depth=6, max_features=0.14031339755327152, n_estimators=52
# [CV 3/5; 1/1] END max_depth=6, max_features=0.14031339755327152, n_estimators=52;, score=0.959 total time=   0.3s
# [CV 4/5; 1/1] START max_depth=6, max_features=0.14031339755327152, n_estimators=52
# [CV 4/5; 1/1] END max_depth=6, max_features=0.14031339755327152, n_estimators=52;, score=0.948 total time=   0.3s
# [CV 5/5; 1/1] START max_depth=6, max_features=0.14031339755327152, n_estimators=52
# [CV 5/5; 1/1] END max_depth=6, max_features=0.14031339755327152, n_estimators=52;, score=0.951 total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, max_features=0.10368981634901368, n_estimators=145
# [CV 1/5; 1/1] END max_depth=10, max_features=0.10368981634901368, n_estimators=145;, score=0.951 total time=   1.7s
# [CV 2/5; 1/1] START max_depth=10, max_features=0.10368981634901368, n_estimators=145
# [CV 2/5; 1/1] END max_depth=10, max_features=0.10368981634901368, n_estimators=145;, score=0.959 total time=   1.3s
# [CV 3/5; 1/1] START max_depth=10, max_features=0.10368981634901368, n_estimators=145
# [CV 3/5; 1/1] END max_depth=10, max_features=0.10368981634901368, n_estimators=145;, score=0.969 total time=   1.3s
# [CV 4/5; 1/1] START max_depth=10, max_features=0.10368981634901368, n_estimators=145
# [CV 4/5; 1/1] END max_depth=10, max_features=0.10368981634901368, n_estimators=145;, score=0.947 total time=   1.3s
# [CV 5/5; 1/1] START max_depth=10, max_features=0.10368981634901368, n_estimators=145
# [CV 5/5; 1/1] END max_depth=10, max_features=0.10368981634901368, n_estimators=145;, score=0.961 total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=6, max_features=0.1, n_estimators=200.............
# [CV 1/5; 1/1] END max_depth=6, max_features=0.1, n_estimators=200;, score=0.951 total time=   0.8s
# [CV 2/5; 1/1] START max_depth=6, max_features=0.1, n_estimators=200.............
# [CV 2/5; 1/1] END max_depth=6, max_features=0.1, n_estimators=200;, score=0.959 total time=   0.8s
# [CV 3/5; 1/1] START max_depth=6, max_features=0.1, n_estimators=200.............
# [CV 3/5; 1/1] END max_depth=6, max_features=0.1, n_estimators=200;, score=0.967 total time=   0.8s
# [CV 4/5; 1/1] START max_depth=6, max_features=0.1, n_estimators=200.............
# [CV 4/5; 1/1] END max_depth=6, max_features=0.1, n_estimators=200;, score=0.947 total time=   0.8s
# [CV 5/5; 1/1] START max_depth=6, max_features=0.1, n_estimators=200.............
# [CV 5/5; 1/1] END max_depth=6, max_features=0.1, n_estimators=200;, score=0.963 total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=171.............
# [CV 1/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=171;, score=0.958 total time=   1.2s
# [CV 2/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=171.............
# [CV 2/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=171;, score=0.962 total time=   1.1s
# [CV 3/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=171.............
# [CV 3/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=171;, score=0.971 total time=   1.0s
# [CV 4/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=171.............
# [CV 4/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=171;, score=0.948 total time=   1.0s
# [CV 5/5; 1/1] START max_depth=8, max_features=0.1, n_estimators=171.............
# [CV 5/5; 1/1] END max_depth=8, max_features=0.1, n_estimators=171;, score=0.957 total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=2, max_features=0.1076983285356119, n_estimators=54
# [CV 1/5; 1/1] END max_depth=2, max_features=0.1076983285356119, n_estimators=54;, score=0.931 total time=   0.1s
# [CV 2/5; 1/1] START max_depth=2, max_features=0.1076983285356119, n_estimators=54
# [CV 2/5; 1/1] END max_depth=2, max_features=0.1076983285356119, n_estimators=54;, score=0.917 total time=   0.1s
# [CV 3/5; 1/1] START max_depth=2, max_features=0.1076983285356119, n_estimators=54
# [CV 3/5; 1/1] END max_depth=2, max_features=0.1076983285356119, n_estimators=54;, score=0.942 total time=   0.1s
# [CV 4/5; 1/1] START max_depth=2, max_features=0.1076983285356119, n_estimators=54
# [CV 4/5; 1/1] END max_depth=2, max_features=0.1076983285356119, n_estimators=54;, score=0.925 total time=   0.1s
# [CV 5/5; 1/1] START max_depth=2, max_features=0.1076983285356119, n_estimators=54
# [CV 5/5; 1/1] END max_depth=2, max_features=0.1076983285356119, n_estimators=54;, score=0.925 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, max_features=0.643879634956828, n_estimators=51
# [CV 1/5; 1/1] END max_depth=10, max_features=0.643879634956828, n_estimators=51;, score=0.947 total time=   1.5s
# [CV 2/5; 1/1] START max_depth=10, max_features=0.643879634956828, n_estimators=51
# [CV 2/5; 1/1] END max_depth=10, max_features=0.643879634956828, n_estimators=51;, score=0.946 total time=   1.6s
# [CV 3/5; 1/1] START max_depth=10, max_features=0.643879634956828, n_estimators=51
# [CV 3/5; 1/1] END max_depth=10, max_features=0.643879634956828, n_estimators=51;, score=0.954 total time=   2.1s
# [CV 4/5; 1/1] START max_depth=10, max_features=0.643879634956828, n_estimators=51
# [CV 4/5; 1/1] END max_depth=10, max_features=0.643879634956828, n_estimators=51;, score=0.944 total time=   1.5s
# [CV 5/5; 1/1] START max_depth=10, max_features=0.643879634956828, n_estimators=51
# [CV 5/5; 1/1] END max_depth=10, max_features=0.643879634956828, n_estimators=51;, score=0.955 total time=   1.4s
# Precisión: 95.5% con {'n_estimators': 200, 'max_features': 0.25, 'max_depth': 6}

# %% [markdown]
# ## HistGradientBoostingClassifier
# Un problema del clasificador GradientBoosting implementado en sklearn es su velocidad. Es un clasificador muy lento de entrenar. Por ello sklearn propone otro tipo de algoritmo de GradientBoosting que soporta paralelismo con OMP además de otras mejoras computacionales basadas en la discretización de las componentes mediante un histograma.
#
# Este otro algoritmo se denomina **HistGradientBoostingClassifier**. Su tiempo de ejecución es mucho mejor. Además se pueden obtener mejores resultados.

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

hgb = HistGradientBoostingClassifier()

acc=hgb.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 95.5%

# %% [markdown]
# **Ejercicio** Analiza en la documentación [HistGradientBoosting](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingClassifier.html) los parámetros más relevantes y realiza una búsqueda de parámetros para obtener el mejor clasificador. A la hora de establecer los valores de los parámetros sería interesante fijarnos en los valores por defecto que se han empleado en el ejercicio anterior y poder explorar alrededor de dichos valores por defecto para conseguir mejores resultados.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import HistGradientBoosting
from sklearn.tree import DecisionTreeClassifier

clf=GradientBoostingClassifier()

G = {"max_depth" : [4,6,8,10], "max_features" : [0.25, 0.5, 1.0], "n_estimators": [100,200,250]}


GS = RandomizedSearchCV(clf,G, scoring='accuracy', n_iter = 10, refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
