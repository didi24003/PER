# %% [markdown]
# # KVecinos en un dataset de detección de spam
#
# Se propone emplear un clasificador basado en distancias sobre el dataset id=44 de openml de detección de Spam. Son un total de 4601 muestras con 57 características.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (4601, 57)

# %% [markdown]
# ## El clasificador por los vecinos más cercanos

# %%
from sklearn.neighbors import KNeighborsClassifier

kv = KNeighborsClassifier()
acc=kv.fit(X_train,y_train).score(X_test,y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 79.5%

# %% [markdown]
# **Ejercicio:** Explora el principal parámetros del KNN (n_neighbors) y realiza una búsqueda mediante alguna técnica de optimización ya vista en la práctica anterior

# %%
from sklearn.model_selection import GridSearchCV;

G = {"n_neighbors": [1,3,4,5,6,7,8]}

GS = GridSearchCV(KNeighborsClassifier(), G, scoring='accuracy',refit=True, cv=5, verbose = 10)

acc=GS.fit(X_train,y_train).score(X_test,y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV 1/5; 1/7] START n_neighbors=1...............................................
# [CV 1/5; 1/7] END ................n_neighbors=1;, score=0.821 total time=   0.1s
# [CV 2/5; 1/7] START n_neighbors=1...............................................
# [CV 2/5; 1/7] END ................n_neighbors=1;, score=0.818 total time=   0.1s
# [CV 3/5; 1/7] START n_neighbors=1...............................................
# [CV 3/5; 1/7] END ................n_neighbors=1;, score=0.829 total time=   0.1s
# [CV 4/5; 1/7] START n_neighbors=1...............................................
# [CV 4/5; 1/7] END ................n_neighbors=1;, score=0.800 total time=   0.1s
# [CV 5/5; 1/7] START n_neighbors=1...............................................
# [CV 5/5; 1/7] END ................n_neighbors=1;, score=0.810 total time=   0.1s
# [CV 1/5; 2/7] START n_neighbors=3...............................................
# [CV 1/5; 2/7] END ................n_neighbors=3;, score=0.791 total time=   0.1s
# [CV 2/5; 2/7] START n_neighbors=3...............................................
# [CV 2/5; 2/7] END ................n_neighbors=3;, score=0.799 total time=   0.1s
# [CV 3/5; 2/7] START n_neighbors=3...............................................
# [CV 3/5; 2/7] END ................n_neighbors=3;, score=0.829 total time=   0.1s
# [CV 4/5; 2/7] START n_neighbors=3...............................................
# [CV 4/5; 2/7] END ................n_neighbors=3;, score=0.788 total time=   0.1s
# [CV 5/5; 2/7] START n_neighbors=3...............................................
# [CV 5/5; 2/7] END ................n_neighbors=3;, score=0.791 total time=   0.1s
# [CV 1/5; 3/7] START n_neighbors=4...............................................
# [CV 1/5; 3/7] END ................n_neighbors=4;, score=0.785 total time=   0.1s
# [CV 2/5; 3/7] START n_neighbors=4...............................................
# [CV 2/5; 3/7] END ................n_neighbors=4;, score=0.789 total time=   0.1s
# [CV 3/5; 3/7] START n_neighbors=4...............................................
# [CV 3/5; 3/7] END ................n_neighbors=4;, score=0.802 total time=   0.1s
# [CV 4/5; 3/7] START n_neighbors=4...............................................
# [CV 4/5; 3/7] END ................n_neighbors=4;, score=0.787 total time=   0.1s
# [CV 5/5; 3/7] START n_neighbors=4...............................................
# [CV 5/5; 3/7] END ................n_neighbors=4;, score=0.776 total time=   0.1s
# [CV 1/5; 4/7] START n_neighbors=5...............................................
# [CV 1/5; 4/7] END ................n_neighbors=5;, score=0.793 total time=   0.1s
# [CV 2/5; 4/7] START n_neighbors=5...............................................
# [CV 2/5; 4/7] END ................n_neighbors=5;, score=0.796 total time=   0.1s
# [CV 3/5; 4/7] START n_neighbors=5...............................................
# [CV 3/5; 4/7] END ................n_neighbors=5;, score=0.815 total time=   0.1s
# [CV 4/5; 4/7] START n_neighbors=5...............................................
# [CV 4/5; 4/7] END ................n_neighbors=5;, score=0.791 total time=   0.1s
# [CV 5/5; 4/7] START n_neighbors=5...............................................
# [CV 5/5; 4/7] END ................n_neighbors=5;, score=0.777 total time=   0.1s
# [CV 1/5; 5/7] START n_neighbors=6...............................................
# [CV 1/5; 5/7] END ................n_neighbors=6;, score=0.777 total time=   0.1s
# [CV 2/5; 5/7] START n_neighbors=6...............................................
# [CV 2/5; 5/7] END ................n_neighbors=6;, score=0.787 total time=   0.1s
# [CV 3/5; 5/7] START n_neighbors=6...............................................
# [CV 3/5; 5/7] END ................n_neighbors=6;, score=0.798 total time=   0.1s
# [CV 4/5; 5/7] START n_neighbors=6...............................................
# [CV 4/5; 5/7] END ................n_neighbors=6;, score=0.777 total time=   0.1s
# [CV 5/5; 5/7] START n_neighbors=6...............................................
# [CV 5/5; 5/7] END ................n_neighbors=6;, score=0.753 total time=   0.1s
# [CV 1/5; 6/7] START n_neighbors=7...............................................
# [CV 1/5; 6/7] END ................n_neighbors=7;, score=0.761 total time=   0.1s
# [CV 2/5; 6/7] START n_neighbors=7...............................................
# [CV 2/5; 6/7] END ................n_neighbors=7;, score=0.793 total time=   0.1s
# [CV 3/5; 6/7] START n_neighbors=7...............................................
# [CV 3/5; 6/7] END ................n_neighbors=7;, score=0.802 total time=   0.1s
# [CV 4/5; 6/7] START n_neighbors=7...............................................
# [CV 4/5; 6/7] END ................n_neighbors=7;, score=0.773 total time=   0.1s
# [CV 5/5; 6/7] START n_neighbors=7...............................................
# [CV 5/5; 6/7] END ................n_neighbors=7;, score=0.776 total time=   0.1s
# [CV 1/5; 7/7] START n_neighbors=8...............................................
# [CV 1/5; 7/7] END ................n_neighbors=8;, score=0.751 total time=   0.1s
# [CV 2/5; 7/7] START n_neighbors=8...............................................
# [CV 2/5; 7/7] END ................n_neighbors=8;, score=0.791 total time=   0.1s
# [CV 3/5; 7/7] START n_neighbors=8...............................................
# [CV 3/5; 7/7] END ................n_neighbors=8;, score=0.791 total time=   0.1s
# [CV 4/5; 7/7] START n_neighbors=8...............................................
# [CV 4/5; 7/7] END ................n_neighbors=8;, score=0.787 total time=   0.1s
# [CV 5/5; 7/7] START n_neighbors=8...............................................
# [CV 5/5; 7/7] END ................n_neighbors=8;, score=0.758 total time=   0.1s
# Precisión: 82.1% con {'n_neighbors': 1}

# %% [markdown]
# ## Mejoras
#
# La función de distancia empleada por defecto es la distancia euclídea. Dicha distancia requiere un preproceso de las muestras para que tengan una escala similar todas ellas. Además KNN podría beneficiarse de una proyección mediante PCA con el fin de reducir la dimensionalidad.
#
# **Ejercicio:** Implementa un pipeline con la normalización de los datos y un PCA, seguido del KNN. Busca los mejores parámetros. Se podría conseguir una tasa de acierto >90%.

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures;
from sklearn.model_selection import train_test_split, GridSearchCV;
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA;
from sklearn.pipeline import Pipeline;

scaler = StandardScaler();
pca = PCA();
knn = KNeighborsClassifier();


pipe = Pipeline(steps=[("scaler", scaler),("pca", pca),("knn", knn)])

G = {"pca__n_components": [5,10,15,20,25,30,35],"knn__n_neighbors" : [1,3,4,5,6,7,8]}
GS = GridSearchCV(pipe, G, scoring='accuracy', refit=True, cv=5, verbose = 10)


acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# [CV 1/5; 1/49] START knn__n_neighbors=1, pca__n_components=5....................
# [CV 1/5; 1/49] END knn__n_neighbors=1, pca__n_components=5;, score=0.883 total time=   0.1s
# [CV 2/5; 1/49] START knn__n_neighbors=1, pca__n_components=5....................
# [CV 2/5; 1/49] END knn__n_neighbors=1, pca__n_components=5;, score=0.909 total time=   0.1s
# [CV 3/5; 1/49] START knn__n_neighbors=1, pca__n_components=5....................
# [CV 3/5; 1/49] END knn__n_neighbors=1, pca__n_components=5;, score=0.882 total time=   0.2s
# [CV 4/5; 1/49] START knn__n_neighbors=1, pca__n_components=5....................
# [CV 4/5; 1/49] END knn__n_neighbors=1, pca__n_components=5;, score=0.893 total time=   0.2s
# [CV 5/5; 1/49] START knn__n_neighbors=1, pca__n_components=5....................
# [CV 5/5; 1/49] END knn__n_neighbors=1, pca__n_components=5;, score=0.906 total time=   0.2s
# [CV 1/5; 2/49] START knn__n_neighbors=1, pca__n_components=10...................
# [CV 1/5; 2/49] END knn__n_neighbors=1, pca__n_components=10;, score=0.898 total time=   0.2s
# [CV 2/5; 2/49] START knn__n_neighbors=1, pca__n_components=10...................
# [CV 2/5; 2/49] END knn__n_neighbors=1, pca__n_components=10;, score=0.916 total time=   0.2s
# [CV 3/5; 2/49] START knn__n_neighbors=1, pca__n_components=10...................
# [CV 3/5; 2/49] END knn__n_neighbors=1, pca__n_components=10;, score=0.890 total time=   0.2s
# [CV 4/5; 2/49] START knn__n_neighbors=1, pca__n_components=10...................
# [CV 4/5; 2/49] END knn__n_neighbors=1, pca__n_components=10;, score=0.910 total time=   0.2s
# [CV 5/5; 2/49] START knn__n_neighbors=1, pca__n_components=10...................
# [CV 5/5; 2/49] END knn__n_neighbors=1, pca__n_components=10;, score=0.912 total time=   0.3s
# [CV 1/5; 3/49] START knn__n_neighbors=1, pca__n_components=15...................
# [CV 1/5; 3/49] END knn__n_neighbors=1, pca__n_components=15;, score=0.901 total time=   0.3s
# [CV 2/5; 3/49] START knn__n_neighbors=1, pca__n_components=15...................
# [CV 2/5; 3/49] END knn__n_neighbors=1, pca__n_components=15;, score=0.920 total time=   0.3s
# [CV 3/5; 3/49] START knn__n_neighbors=1, pca__n_components=15...................
# [CV 3/5; 3/49] END knn__n_neighbors=1, pca__n_components=15;, score=0.899 total time=   0.3s
# [CV 4/5; 3/49] START knn__n_neighbors=1, pca__n_components=15...................
# [CV 4/5; 3/49] END knn__n_neighbors=1, pca__n_components=15;, score=0.897 total time=   0.3s
# [CV 5/5; 3/49] START knn__n_neighbors=1, pca__n_components=15...................
# [CV 5/5; 3/49] END knn__n_neighbors=1, pca__n_components=15;, score=0.925 total time=   0.3s
# [CV 1/5; 4/49] START knn__n_neighbors=1, pca__n_components=20...................
# [CV 1/5; 4/49] END knn__n_neighbors=1, pca__n_components=20;, score=0.897 total time=   0.3s
# [CV 2/5; 4/49] START knn__n_neighbors=1, pca__n_components=20...................
# [CV 2/5; 4/49] END knn__n_neighbors=1, pca__n_components=20;, score=0.929 total time=   0.2s
# [CV 3/5; 4/49] START knn__n_neighbors=1, pca__n_components=20...................
# [CV 3/5; 4/49] END knn__n_neighbors=1, pca__n_components=20;, score=0.910 total time=   0.2s
# [CV 4/5; 4/49] START knn__n_neighbors=1, pca__n_components=20...................
# [CV 4/5; 4/49] END knn__n_neighbors=1, pca__n_components=20;, score=0.899 total time=   0.2s
# [CV 5/5; 4/49] START knn__n_neighbors=1, pca__n_components=20...................
# [CV 5/5; 4/49] END knn__n_neighbors=1, pca__n_components=20;, score=0.923 total time=   0.2s
# [CV 1/5; 5/49] START knn__n_neighbors=1, pca__n_components=25...................
# [CV 1/5; 5/49] END knn__n_neighbors=1, pca__n_components=25;, score=0.889 total time=   0.2s
# [CV 2/5; 5/49] START knn__n_neighbors=1, pca__n_components=25...................
# [CV 2/5; 5/49] END knn__n_neighbors=1, pca__n_components=25;, score=0.925 total time=   0.2s
# [CV 3/5; 5/49] START knn__n_neighbors=1, pca__n_components=25...................
# [CV 3/5; 5/49] END knn__n_neighbors=1, pca__n_components=25;, score=0.910 total time=   0.2s
# [CV 4/5; 5/49] START knn__n_neighbors=1, pca__n_components=25...................
# [CV 4/5; 5/49] END knn__n_neighbors=1, pca__n_components=25;, score=0.895 total time=   0.2s
# [CV 5/5; 5/49] START knn__n_neighbors=1, pca__n_components=25...................
# [CV 5/5; 5/49] END knn__n_neighbors=1, pca__n_components=25;, score=0.921 total time=   0.2s
# [CV 1/5; 6/49] START knn__n_neighbors=1, pca__n_components=30...................
# [CV 1/5; 6/49] END knn__n_neighbors=1, pca__n_components=30;, score=0.904 total time=   0.2s
# [CV 2/5; 6/49] START knn__n_neighbors=1, pca__n_components=30...................
# [CV 2/5; 6/49] END knn__n_neighbors=1, pca__n_components=30;, score=0.901 total time=   0.2s
# [CV 3/5; 6/49] START knn__n_neighbors=1, pca__n_components=30...................
# [CV 3/5; 6/49] END knn__n_neighbors=1, pca__n_components=30;, score=0.909 total time=   0.2s
# [CV 4/5; 6/49] START knn__n_neighbors=1, pca__n_components=30...................
# [CV 4/5; 6/49] END knn__n_neighbors=1, pca__n_components=30;, score=0.905 total time=   0.2s
# [CV 5/5; 6/49] START knn__n_neighbors=1, pca__n_components=30...................
# [CV 5/5; 6/49] END knn__n_neighbors=1, pca__n_components=30;, score=0.918 total time=   0.2s
# [CV 1/5; 7/49] START knn__n_neighbors=1, pca__n_components=35...................
# [CV 1/5; 7/49] END knn__n_neighbors=1, pca__n_components=35;, score=0.886 total time=   0.2s
# [CV 2/5; 7/49] START knn__n_neighbors=1, pca__n_components=35...................
# [CV 2/5; 7/49] END knn__n_neighbors=1, pca__n_components=35;, score=0.921 total time=   0.2s
# [CV 3/5; 7/49] START knn__n_neighbors=1, pca__n_components=35...................
# [CV 3/5; 7/49] END knn__n_neighbors=1, pca__n_components=35;, score=0.912 total time=   0.2s
# [CV 4/5; 7/49] START knn__n_neighbors=1, pca__n_components=35...................
# [CV 4/5; 7/49] END knn__n_neighbors=1, pca__n_components=35;, score=0.898 total time=   0.1s
# [CV 5/5; 7/49] START knn__n_neighbors=1, pca__n_components=35...................
# [CV 5/5; 7/49] END knn__n_neighbors=1, pca__n_components=35;, score=0.921 total time=   0.2s
# [CV 1/5; 8/49] START knn__n_neighbors=3, pca__n_components=5....................
# [CV 1/5; 8/49] END knn__n_neighbors=3, pca__n_components=5;, score=0.872 total time=   0.2s
# [CV 2/5; 8/49] START knn__n_neighbors=3, pca__n_components=5....................
# [CV 2/5; 8/49] END knn__n_neighbors=3, pca__n_components=5;, score=0.905 total time=   0.2s
# [CV 3/5; 8/49] START knn__n_neighbors=3, pca__n_components=5....................
# [CV 3/5; 8/49] END knn__n_neighbors=3, pca__n_components=5;, score=0.899 total time=   0.2s
# [CV 4/5; 8/49] START knn__n_neighbors=3, pca__n_components=5....................
# [CV 4/5; 8/49] END knn__n_neighbors=3, pca__n_components=5;, score=0.901 total time=   0.2s
# [CV 5/5; 8/49] START knn__n_neighbors=3, pca__n_components=5....................
# [CV 5/5; 8/49] END knn__n_neighbors=3, pca__n_components=5;, score=0.908 total time=   0.1s
# [CV 1/5; 9/49] START knn__n_neighbors=3, pca__n_components=10...................
# [CV 1/5; 9/49] END knn__n_neighbors=3, pca__n_components=10;, score=0.890 total time=   0.2s
# [CV 2/5; 9/49] START knn__n_neighbors=3, pca__n_components=10...................
# [CV 2/5; 9/49] END knn__n_neighbors=3, pca__n_components=10;, score=0.924 total time=   0.1s
# [CV 3/5; 9/49] START knn__n_neighbors=3, pca__n_components=10...................
# [CV 3/5; 9/49] END knn__n_neighbors=3, pca__n_components=10;, score=0.920 total time=   0.2s
# [CV 4/5; 9/49] START knn__n_neighbors=3, pca__n_components=10...................
# [CV 4/5; 9/49] END knn__n_neighbors=3, pca__n_components=10;, score=0.906 total time=   0.2s
# [CV 5/5; 9/49] START knn__n_neighbors=3, pca__n_components=10...................
# [CV 5/5; 9/49] END knn__n_neighbors=3, pca__n_components=10;, score=0.910 total time=   0.2s
# [CV 1/5; 10/49] START knn__n_neighbors=3, pca__n_components=15..................
# [CV 1/5; 10/49] END knn__n_neighbors=3, pca__n_components=15;, score=0.905 total time=   0.2s
# [CV 2/5; 10/49] START knn__n_neighbors=3, pca__n_components=15..................
# [CV 2/5; 10/49] END knn__n_neighbors=3, pca__n_components=15;, score=0.927 total time=   0.2s
# [CV 3/5; 10/49] START knn__n_neighbors=3, pca__n_components=15..................
# [CV 3/5; 10/49] END knn__n_neighbors=3, pca__n_components=15;, score=0.925 total time=   0.2s
# [CV 4/5; 10/49] START knn__n_neighbors=3, pca__n_components=15..................
# [CV 4/5; 10/49] END knn__n_neighbors=3, pca__n_components=15;, score=0.910 total time=   0.2s
# [CV 5/5; 10/49] START knn__n_neighbors=3, pca__n_components=15..................
# [CV 5/5; 10/49] END knn__n_neighbors=3, pca__n_components=15;, score=0.925 total time=   0.2s
# [CV 1/5; 11/49] START knn__n_neighbors=3, pca__n_components=20..................
# [CV 1/5; 11/49] END knn__n_neighbors=3, pca__n_components=20;, score=0.905 total time=   0.2s
# [CV 2/5; 11/49] START knn__n_neighbors=3, pca__n_components=20..................
# [CV 2/5; 11/49] END knn__n_neighbors=3, pca__n_components=20;, score=0.928 total time=   0.2s
# [CV 3/5; 11/49] START knn__n_neighbors=3, pca__n_components=20..................
# [CV 3/5; 11/49] END knn__n_neighbors=3, pca__n_components=20;, score=0.924 total time=   0.2s
# [CV 4/5; 11/49] START knn__n_neighbors=3, pca__n_components=20..................
# [CV 4/5; 11/49] END knn__n_neighbors=3, pca__n_components=20;, score=0.901 total time=   0.2s
# [CV 5/5; 11/49] START knn__n_neighbors=3, pca__n_components=20..................
# [CV 5/5; 11/49] END knn__n_neighbors=3, pca__n_components=20;, score=0.917 total time=   0.2s
# [CV 1/5; 12/49] START knn__n_neighbors=3, pca__n_components=25..................
# [CV 1/5; 12/49] END knn__n_neighbors=3, pca__n_components=25;, score=0.902 total time=   0.2s
# [CV 2/5; 12/49] START knn__n_neighbors=3, pca__n_components=25..................
# [CV 2/5; 12/49] END knn__n_neighbors=3, pca__n_components=25;, score=0.917 total time=   0.2s
# [CV 3/5; 12/49] START knn__n_neighbors=3, pca__n_components=25..................
# [CV 3/5; 12/49] END knn__n_neighbors=3, pca__n_components=25;, score=0.939 total time=   0.1s
# [CV 4/5; 12/49] START knn__n_neighbors=3, pca__n_components=25..................
# [CV 4/5; 12/49] END knn__n_neighbors=3, pca__n_components=25;, score=0.895 total time=   0.2s
# [CV 5/5; 12/49] START knn__n_neighbors=3, pca__n_components=25..................
# [CV 5/5; 12/49] END knn__n_neighbors=3, pca__n_components=25;, score=0.920 total time=   0.2s
# [CV 1/5; 13/49] START knn__n_neighbors=3, pca__n_components=30..................
# [CV 1/5; 13/49] END knn__n_neighbors=3, pca__n_components=30;, score=0.904 total time=   0.2s
# [CV 2/5; 13/49] START knn__n_neighbors=3, pca__n_components=30..................
# [CV 2/5; 13/49] END knn__n_neighbors=3, pca__n_components=30;, score=0.918 total time=   0.2s
# [CV 3/5; 13/49] START knn__n_neighbors=3, pca__n_components=30..................
# [CV 3/5; 13/49] END knn__n_neighbors=3, pca__n_components=30;, score=0.932 total time=   0.2s
# [CV 4/5; 13/49] START knn__n_neighbors=3, pca__n_components=30..................
# [CV 4/5; 13/49] END knn__n_neighbors=3, pca__n_components=30;, score=0.893 total time=   0.2s
# [CV 5/5; 13/49] START knn__n_neighbors=3, pca__n_components=30..................
# [CV 5/5; 13/49] END knn__n_neighbors=3, pca__n_components=30;, score=0.920 total time=   0.2s
# [CV 1/5; 14/49] START knn__n_neighbors=3, pca__n_components=35..................
# [CV 1/5; 14/49] END knn__n_neighbors=3, pca__n_components=35;, score=0.891 total time=   0.2s
# [CV 2/5; 14/49] START knn__n_neighbors=3, pca__n_components=35..................
# [CV 2/5; 14/49] END knn__n_neighbors=3, pca__n_components=35;, score=0.918 total time=   0.1s
# [CV 3/5; 14/49] START knn__n_neighbors=3, pca__n_components=35..................
# [CV 3/5; 14/49] END knn__n_neighbors=3, pca__n_components=35;, score=0.928 total time=   0.2s
# [CV 4/5; 14/49] START knn__n_neighbors=3, pca__n_components=35..................
# [CV 4/5; 14/49] END knn__n_neighbors=3, pca__n_components=35;, score=0.895 total time=   0.3s
# [CV 5/5; 14/49] START knn__n_neighbors=3, pca__n_components=35..................
# [CV 5/5; 14/49] END knn__n_neighbors=3, pca__n_components=35;, score=0.905 total time=   0.3s
# [CV 1/5; 15/49] START knn__n_neighbors=4, pca__n_components=5...................
# [CV 1/5; 15/49] END knn__n_neighbors=4, pca__n_components=5;, score=0.870 total time=   0.2s
# [CV 2/5; 15/49] START knn__n_neighbors=4, pca__n_components=5...................
# [CV 2/5; 15/49] END knn__n_neighbors=4, pca__n_components=5;, score=0.890 total time=   0.2s
# [CV 3/5; 15/49] START knn__n_neighbors=4, pca__n_components=5...................
# [CV 3/5; 15/49] END knn__n_neighbors=4, pca__n_components=5;, score=0.895 total time=   0.2s
# [CV 4/5; 15/49] START knn__n_neighbors=4, pca__n_components=5...................
# [CV 4/5; 15/49] END knn__n_neighbors=4, pca__n_components=5;, score=0.889 total time=   0.2s
# [CV 5/5; 15/49] START knn__n_neighbors=4, pca__n_components=5...................
# [CV 5/5; 15/49] END knn__n_neighbors=4, pca__n_components=5;, score=0.910 total time=   0.2s
# [CV 1/5; 16/49] START knn__n_neighbors=4, pca__n_components=10..................
# [CV 1/5; 16/49] END knn__n_neighbors=4, pca__n_components=10;, score=0.886 total time=   0.3s
# [CV 2/5; 16/49] START knn__n_neighbors=4, pca__n_components=10..................
# [CV 2/5; 16/49] END knn__n_neighbors=4, pca__n_components=10;, score=0.909 total time=   0.2s
# [CV 3/5; 16/49] START knn__n_neighbors=4, pca__n_components=10..................
# [CV 3/5; 16/49] END knn__n_neighbors=4, pca__n_components=10;, score=0.910 total time=   0.2s
# [CV 4/5; 16/49] START knn__n_neighbors=4, pca__n_components=10..................
# [CV 4/5; 16/49] END knn__n_neighbors=4, pca__n_components=10;, score=0.893 total time=   0.2s
# [CV 5/5; 16/49] START knn__n_neighbors=4, pca__n_components=10..................
# [CV 5/5; 16/49] END knn__n_neighbors=4, pca__n_components=10;, score=0.912 total time=   0.2s
# [CV 1/5; 17/49] START knn__n_neighbors=4, pca__n_components=15..................
# [CV 1/5; 17/49] END knn__n_neighbors=4, pca__n_components=15;, score=0.909 total time=   0.3s
# [CV 2/5; 17/49] START knn__n_neighbors=4, pca__n_components=15..................
# [CV 2/5; 17/49] END knn__n_neighbors=4, pca__n_components=15;, score=0.921 total time=   0.3s
# [CV 3/5; 17/49] START knn__n_neighbors=4, pca__n_components=15..................
# [CV 3/5; 17/49] END knn__n_neighbors=4, pca__n_components=15;, score=0.921 total time=   0.3s
# [CV 4/5; 17/49] START knn__n_neighbors=4, pca__n_components=15..................
# [CV 4/5; 17/49] END knn__n_neighbors=4, pca__n_components=15;, score=0.899 total time=   0.3s
# [CV 5/5; 17/49] START knn__n_neighbors=4, pca__n_components=15..................
# [CV 5/5; 17/49] END knn__n_neighbors=4, pca__n_components=15;, score=0.910 total time=   0.2s
# [CV 1/5; 18/49] START knn__n_neighbors=4, pca__n_components=20..................
# [CV 1/5; 18/49] END knn__n_neighbors=4, pca__n_components=20;, score=0.902 total time=   0.2s
# [CV 2/5; 18/49] START knn__n_neighbors=4, pca__n_components=20..................
# [CV 2/5; 18/49] END knn__n_neighbors=4, pca__n_components=20;, score=0.920 total time=   0.2s
# [CV 3/5; 18/49] START knn__n_neighbors=4, pca__n_components=20..................
# [CV 3/5; 18/49] END knn__n_neighbors=4, pca__n_components=20;, score=0.913 total time=   0.2s
# [CV 4/5; 18/49] START knn__n_neighbors=4, pca__n_components=20..................
# [CV 4/5; 18/49] END knn__n_neighbors=4, pca__n_components=20;, score=0.910 total time=   0.2s
# [CV 5/5; 18/49] START knn__n_neighbors=4, pca__n_components=20..................
# [CV 5/5; 18/49] END knn__n_neighbors=4, pca__n_components=20;, score=0.920 total time=   0.2s
# [CV 1/5; 19/49] START knn__n_neighbors=4, pca__n_components=25..................
# [CV 1/5; 19/49] END knn__n_neighbors=4, pca__n_components=25;, score=0.904 total time=   0.1s
# [CV 2/5; 19/49] START knn__n_neighbors=4, pca__n_components=25..................
# [CV 2/5; 19/49] END knn__n_neighbors=4, pca__n_components=25;, score=0.918 total time=   0.2s
# [CV 3/5; 19/49] START knn__n_neighbors=4, pca__n_components=25..................
# [CV 3/5; 19/49] END knn__n_neighbors=4, pca__n_components=25;, score=0.924 total time=   0.2s
# [CV 4/5; 19/49] START knn__n_neighbors=4, pca__n_components=25..................
# [CV 4/5; 19/49] END knn__n_neighbors=4, pca__n_components=25;, score=0.905 total time=   0.2s
# [CV 5/5; 19/49] START knn__n_neighbors=4, pca__n_components=25..................
# [CV 5/5; 19/49] END knn__n_neighbors=4, pca__n_components=25;, score=0.914 total time=   0.2s
# [CV 1/5; 20/49] START knn__n_neighbors=4, pca__n_components=30..................
# [CV 1/5; 20/49] END knn__n_neighbors=4, pca__n_components=30;, score=0.891 total time=   0.2s
# [CV 2/5; 20/49] START knn__n_neighbors=4, pca__n_components=30..................
# [CV 2/5; 20/49] END knn__n_neighbors=4, pca__n_components=30;, score=0.920 total time=   0.2s
# [CV 3/5; 20/49] START knn__n_neighbors=4, pca__n_components=30..................
# [CV 3/5; 20/49] END knn__n_neighbors=4, pca__n_components=30;, score=0.918 total time=   0.2s
# [CV 4/5; 20/49] START knn__n_neighbors=4, pca__n_components=30..................
# [CV 4/5; 20/49] END knn__n_neighbors=4, pca__n_components=30;, score=0.894 total time=   0.2s
# [CV 5/5; 20/49] START knn__n_neighbors=4, pca__n_components=30..................
# [CV 5/5; 20/49] END knn__n_neighbors=4, pca__n_components=30;, score=0.913 total time=   0.2s
# [CV 1/5; 21/49] START knn__n_neighbors=4, pca__n_components=35..................
# [CV 1/5; 21/49] END knn__n_neighbors=4, pca__n_components=35;, score=0.893 total time=   0.2s
# [CV 2/5; 21/49] START knn__n_neighbors=4, pca__n_components=35..................
# [CV 2/5; 21/49] END knn__n_neighbors=4, pca__n_components=35;, score=0.920 total time=   0.2s
# [CV 3/5; 21/49] START knn__n_neighbors=4, pca__n_components=35..................
# [CV 3/5; 21/49] END knn__n_neighbors=4, pca__n_components=35;, score=0.912 total time=   0.2s
# [CV 4/5; 21/49] START knn__n_neighbors=4, pca__n_components=35..................
# [CV 4/5; 21/49] END knn__n_neighbors=4, pca__n_components=35;, score=0.901 total time=   0.2s
# [CV 5/5; 21/49] START knn__n_neighbors=4, pca__n_components=35..................
# [CV 5/5; 21/49] END knn__n_neighbors=4, pca__n_components=35;, score=0.898 total time=   0.2s
# [CV 1/5; 22/49] START knn__n_neighbors=5, pca__n_components=5...................
# [CV 1/5; 22/49] END knn__n_neighbors=5, pca__n_components=5;, score=0.876 total time=   0.1s
# [CV 2/5; 22/49] START knn__n_neighbors=5, pca__n_components=5...................
# [CV 2/5; 22/49] END knn__n_neighbors=5, pca__n_components=5;, score=0.912 total time=   0.1s
# [CV 3/5; 22/49] START knn__n_neighbors=5, pca__n_components=5...................
# [CV 3/5; 22/49] END knn__n_neighbors=5, pca__n_components=5;, score=0.901 total time=   0.1s
# [CV 4/5; 22/49] START knn__n_neighbors=5, pca__n_components=5...................
# [CV 4/5; 22/49] END knn__n_neighbors=5, pca__n_components=5;, score=0.893 total time=   0.2s
# [CV 5/5; 22/49] START knn__n_neighbors=5, pca__n_components=5...................
# [CV 5/5; 22/49] END knn__n_neighbors=5, pca__n_components=5;, score=0.912 total time=   0.1s
# [CV 1/5; 23/49] START knn__n_neighbors=5, pca__n_components=10..................
# [CV 1/5; 23/49] END knn__n_neighbors=5, pca__n_components=10;, score=0.898 total time=   0.1s
# [CV 2/5; 23/49] START knn__n_neighbors=5, pca__n_components=10..................
# [CV 2/5; 23/49] END knn__n_neighbors=5, pca__n_components=10;, score=0.916 total time=   0.2s
# [CV 3/5; 23/49] START knn__n_neighbors=5, pca__n_components=10..................
# [CV 3/5; 23/49] END knn__n_neighbors=5, pca__n_components=10;, score=0.917 total time=   0.1s
# [CV 4/5; 23/49] START knn__n_neighbors=5, pca__n_components=10..................
# [CV 4/5; 23/49] END knn__n_neighbors=5, pca__n_components=10;, score=0.901 total time=   0.2s
# [CV 5/5; 23/49] START knn__n_neighbors=5, pca__n_components=10..................
# [CV 5/5; 23/49] END knn__n_neighbors=5, pca__n_components=10;, score=0.916 total time=   0.1s
# [CV 1/5; 24/49] START knn__n_neighbors=5, pca__n_components=15..................
# [CV 1/5; 24/49] END knn__n_neighbors=5, pca__n_components=15;, score=0.893 total time=   0.2s
# [CV 2/5; 24/49] START knn__n_neighbors=5, pca__n_components=15..................
# [CV 2/5; 24/49] END knn__n_neighbors=5, pca__n_components=15;, score=0.925 total time=   0.2s
# [CV 3/5; 24/49] START knn__n_neighbors=5, pca__n_components=15..................
# [CV 3/5; 24/49] END knn__n_neighbors=5, pca__n_components=15;, score=0.921 total time=   0.2s
# [CV 4/5; 24/49] START knn__n_neighbors=5, pca__n_components=15..................
# [CV 4/5; 24/49] END knn__n_neighbors=5, pca__n_components=15;, score=0.902 total time=   0.2s
# [CV 5/5; 24/49] START knn__n_neighbors=5, pca__n_components=15..................
# [CV 5/5; 24/49] END knn__n_neighbors=5, pca__n_components=15;, score=0.923 total time=   0.2s
# [CV 1/5; 25/49] START knn__n_neighbors=5, pca__n_components=20..................
# [CV 1/5; 25/49] END knn__n_neighbors=5, pca__n_components=20;, score=0.906 total time=   0.2s
# [CV 2/5; 25/49] START knn__n_neighbors=5, pca__n_components=20..................
# [CV 2/5; 25/49] END knn__n_neighbors=5, pca__n_components=20;, score=0.920 total time=   0.2s
# [CV 3/5; 25/49] START knn__n_neighbors=5, pca__n_components=20..................
# [CV 3/5; 25/49] END knn__n_neighbors=5, pca__n_components=20;, score=0.925 total time=   0.2s
# [CV 4/5; 25/49] START knn__n_neighbors=5, pca__n_components=20..................
# [CV 4/5; 25/49] END knn__n_neighbors=5, pca__n_components=20;, score=0.902 total time=   0.2s
# [CV 5/5; 25/49] START knn__n_neighbors=5, pca__n_components=20..................
# [CV 5/5; 25/49] END knn__n_neighbors=5, pca__n_components=20;, score=0.924 total time=   0.2s
# [CV 1/5; 26/49] START knn__n_neighbors=5, pca__n_components=25..................
# [CV 1/5; 26/49] END knn__n_neighbors=5, pca__n_components=25;, score=0.905 total time=   0.2s
# [CV 2/5; 26/49] START knn__n_neighbors=5, pca__n_components=25..................
# [CV 2/5; 26/49] END knn__n_neighbors=5, pca__n_components=25;, score=0.917 total time=   0.2s
# [CV 3/5; 26/49] START knn__n_neighbors=5, pca__n_components=25..................
# [CV 3/5; 26/49] END knn__n_neighbors=5, pca__n_components=25;, score=0.925 total time=   0.2s
# [CV 4/5; 26/49] START knn__n_neighbors=5, pca__n_components=25..................
# [CV 4/5; 26/49] END knn__n_neighbors=5, pca__n_components=25;, score=0.910 total time=   0.2s
# [CV 5/5; 26/49] START knn__n_neighbors=5, pca__n_components=25..................
# [CV 5/5; 26/49] END knn__n_neighbors=5, pca__n_components=25;, score=0.921 total time=   0.2s
# [CV 1/5; 27/49] START knn__n_neighbors=5, pca__n_components=30..................
# [CV 1/5; 27/49] END knn__n_neighbors=5, pca__n_components=30;, score=0.890 total time=   0.2s
# [CV 2/5; 27/49] START knn__n_neighbors=5, pca__n_components=30..................
# [CV 2/5; 27/49] END knn__n_neighbors=5, pca__n_components=30;, score=0.917 total time=   0.2s
# [CV 3/5; 27/49] START knn__n_neighbors=5, pca__n_components=30..................
# [CV 3/5; 27/49] END knn__n_neighbors=5, pca__n_components=30;, score=0.916 total time=   0.2s
# [CV 4/5; 27/49] START knn__n_neighbors=5, pca__n_components=30..................
# [CV 4/5; 27/49] END knn__n_neighbors=5, pca__n_components=30;, score=0.898 total time=   0.2s
# [CV 5/5; 27/49] START knn__n_neighbors=5, pca__n_components=30..................
# [CV 5/5; 27/49] END knn__n_neighbors=5, pca__n_components=30;, score=0.914 total time=   0.2s
# [CV 1/5; 28/49] START knn__n_neighbors=5, pca__n_components=35..................
# [CV 1/5; 28/49] END knn__n_neighbors=5, pca__n_components=35;, score=0.898 total time=   0.3s
# [CV 2/5; 28/49] START knn__n_neighbors=5, pca__n_components=35..................
# [CV 2/5; 28/49] END knn__n_neighbors=5, pca__n_components=35;, score=0.924 total time=   0.5s
# [CV 3/5; 28/49] START knn__n_neighbors=5, pca__n_components=35..................
# [CV 3/5; 28/49] END knn__n_neighbors=5, pca__n_components=35;, score=0.920 total time=   0.6s
# [CV 4/5; 28/49] START knn__n_neighbors=5, pca__n_components=35..................
# [CV 4/5; 28/49] END knn__n_neighbors=5, pca__n_components=35;, score=0.901 total time=   0.6s
# [CV 5/5; 28/49] START knn__n_neighbors=5, pca__n_components=35..................
# [CV 5/5; 28/49] END knn__n_neighbors=5, pca__n_components=35;, score=0.916 total time=   0.6s
# [CV 1/5; 29/49] START knn__n_neighbors=6, pca__n_components=5...................
# [CV 1/5; 29/49] END knn__n_neighbors=6, pca__n_components=5;, score=0.864 total time=   0.2s
# [CV 2/5; 29/49] START knn__n_neighbors=6, pca__n_components=5...................
# [CV 2/5; 29/49] END knn__n_neighbors=6, pca__n_components=5;, score=0.894 total time=   0.2s
# [CV 3/5; 29/49] START knn__n_neighbors=6, pca__n_components=5...................
# [CV 3/5; 29/49] END knn__n_neighbors=6, pca__n_components=5;, score=0.899 total time=   0.2s
# [CV 4/5; 29/49] START knn__n_neighbors=6, pca__n_components=5...................
# [CV 4/5; 29/49] END knn__n_neighbors=6, pca__n_components=5;, score=0.898 total time=   0.2s
# [CV 5/5; 29/49] START knn__n_neighbors=6, pca__n_components=5...................
# [CV 5/5; 29/49] END knn__n_neighbors=6, pca__n_components=5;, score=0.902 total time=   0.2s
# [CV 1/5; 30/49] START knn__n_neighbors=6, pca__n_components=10..................
# [CV 1/5; 30/49] END knn__n_neighbors=6, pca__n_components=10;, score=0.890 total time=   0.3s
# [CV 2/5; 30/49] START knn__n_neighbors=6, pca__n_components=10..................
# [CV 2/5; 30/49] END knn__n_neighbors=6, pca__n_components=10;, score=0.918 total time=   0.2s
# [CV 3/5; 30/49] START knn__n_neighbors=6, pca__n_components=10..................
# [CV 3/5; 30/49] END knn__n_neighbors=6, pca__n_components=10;, score=0.923 total time=   0.2s
# [CV 4/5; 30/49] START knn__n_neighbors=6, pca__n_components=10..................
# [CV 4/5; 30/49] END knn__n_neighbors=6, pca__n_components=10;, score=0.905 total time=   0.2s
# [CV 5/5; 30/49] START knn__n_neighbors=6, pca__n_components=10..................
# [CV 5/5; 30/49] END knn__n_neighbors=6, pca__n_components=10;, score=0.924 total time=   0.1s
# [CV 1/5; 31/49] START knn__n_neighbors=6, pca__n_components=15..................
# [CV 1/5; 31/49] END knn__n_neighbors=6, pca__n_components=15;, score=0.902 total time=   0.2s
# [CV 2/5; 31/49] START knn__n_neighbors=6, pca__n_components=15..................
# [CV 2/5; 31/49] END knn__n_neighbors=6, pca__n_components=15;, score=0.912 total time=   0.2s
# [CV 3/5; 31/49] START knn__n_neighbors=6, pca__n_components=15..................
# [CV 3/5; 31/49] END knn__n_neighbors=6, pca__n_components=15;, score=0.918 total time=   0.2s
# [CV 4/5; 31/49] START knn__n_neighbors=6, pca__n_components=15..................
# [CV 4/5; 31/49] END knn__n_neighbors=6, pca__n_components=15;, score=0.910 total time=   0.2s
# [CV 5/5; 31/49] START knn__n_neighbors=6, pca__n_components=15..................
# [CV 5/5; 31/49] END knn__n_neighbors=6, pca__n_components=15;, score=0.918 total time=   0.2s
# [CV 1/5; 32/49] START knn__n_neighbors=6, pca__n_components=20..................
# [CV 1/5; 32/49] END knn__n_neighbors=6, pca__n_components=20;, score=0.895 total time=   0.1s
# [CV 2/5; 32/49] START knn__n_neighbors=6, pca__n_components=20..................
# [CV 2/5; 32/49] END knn__n_neighbors=6, pca__n_components=20;, score=0.917 total time=   0.2s
# [CV 3/5; 32/49] START knn__n_neighbors=6, pca__n_components=20..................
# [CV 3/5; 32/49] END knn__n_neighbors=6, pca__n_components=20;, score=0.912 total time=   0.2s
# [CV 4/5; 32/49] START knn__n_neighbors=6, pca__n_components=20..................
# [CV 4/5; 32/49] END knn__n_neighbors=6, pca__n_components=20;, score=0.904 total time=   0.2s
# [CV 5/5; 32/49] START knn__n_neighbors=6, pca__n_components=20..................
# [CV 5/5; 32/49] END knn__n_neighbors=6, pca__n_components=20;, score=0.924 total time=   0.2s
# [CV 1/5; 33/49] START knn__n_neighbors=6, pca__n_components=25..................
# [CV 1/5; 33/49] END knn__n_neighbors=6, pca__n_components=25;, score=0.904 total time=   0.1s
# [CV 2/5; 33/49] START knn__n_neighbors=6, pca__n_components=25..................
# [CV 2/5; 33/49] END knn__n_neighbors=6, pca__n_components=25;, score=0.914 total time=   0.2s
# [CV 3/5; 33/49] START knn__n_neighbors=6, pca__n_components=25..................
# [CV 3/5; 33/49] END knn__n_neighbors=6, pca__n_components=25;, score=0.920 total time=   0.2s
# [CV 4/5; 33/49] START knn__n_neighbors=6, pca__n_components=25..................
# [CV 4/5; 33/49] END knn__n_neighbors=6, pca__n_components=25;, score=0.906 total time=   0.1s
# [CV 5/5; 33/49] START knn__n_neighbors=6, pca__n_components=25..................
# [CV 5/5; 33/49] END knn__n_neighbors=6, pca__n_components=25;, score=0.924 total time=   0.2s
# [CV 1/5; 34/49] START knn__n_neighbors=6, pca__n_components=30..................
# [CV 1/5; 34/49] END knn__n_neighbors=6, pca__n_components=30;, score=0.899 total time=   0.2s
# [CV 2/5; 34/49] START knn__n_neighbors=6, pca__n_components=30..................
# [CV 2/5; 34/49] END knn__n_neighbors=6, pca__n_components=30;, score=0.898 total time=   0.2s
# [CV 3/5; 34/49] START knn__n_neighbors=6, pca__n_components=30..................
# [CV 3/5; 34/49] END knn__n_neighbors=6, pca__n_components=30;, score=0.916 total time=   0.2s
# [CV 4/5; 34/49] START knn__n_neighbors=6, pca__n_components=30..................
# [CV 4/5; 34/49] END knn__n_neighbors=6, pca__n_components=30;, score=0.894 total time=   0.2s
# [CV 5/5; 34/49] START knn__n_neighbors=6, pca__n_components=30..................
# [CV 5/5; 34/49] END knn__n_neighbors=6, pca__n_components=30;, score=0.918 total time=   0.2s
# [CV 1/5; 35/49] START knn__n_neighbors=6, pca__n_components=35..................
# [CV 1/5; 35/49] END knn__n_neighbors=6, pca__n_components=35;, score=0.889 total time=   0.2s
# [CV 2/5; 35/49] START knn__n_neighbors=6, pca__n_components=35..................
# [CV 2/5; 35/49] END knn__n_neighbors=6, pca__n_components=35;, score=0.904 total time=   0.2s
# [CV 3/5; 35/49] START knn__n_neighbors=6, pca__n_components=35..................
# [CV 3/5; 35/49] END knn__n_neighbors=6, pca__n_components=35;, score=0.918 total time=   0.2s
# [CV 4/5; 35/49] START knn__n_neighbors=6, pca__n_components=35..................
# [CV 4/5; 35/49] END knn__n_neighbors=6, pca__n_components=35;, score=0.902 total time=   0.2s
# [CV 5/5; 35/49] START knn__n_neighbors=6, pca__n_components=35..................
# [CV 5/5; 35/49] END knn__n_neighbors=6, pca__n_components=35;, score=0.909 total time=   0.2s
# [CV 1/5; 36/49] START knn__n_neighbors=7, pca__n_components=5...................
# [CV 1/5; 36/49] END knn__n_neighbors=7, pca__n_components=5;, score=0.868 total time=   0.1s
# [CV 2/5; 36/49] START knn__n_neighbors=7, pca__n_components=5...................
# [CV 2/5; 36/49] END knn__n_neighbors=7, pca__n_components=5;, score=0.901 total time=   0.1s
# [CV 3/5; 36/49] START knn__n_neighbors=7, pca__n_components=5...................
# [CV 3/5; 36/49] END knn__n_neighbors=7, pca__n_components=5;, score=0.905 total time=   0.2s
# [CV 4/5; 36/49] START knn__n_neighbors=7, pca__n_components=5...................
# [CV 4/5; 36/49] END knn__n_neighbors=7, pca__n_components=5;, score=0.893 total time=   0.1s
# [CV 5/5; 36/49] START knn__n_neighbors=7, pca__n_components=5...................
# [CV 5/5; 36/49] END knn__n_neighbors=7, pca__n_components=5;, score=0.905 total time=   0.1s
# [CV 1/5; 37/49] START knn__n_neighbors=7, pca__n_components=10..................
# [CV 1/5; 37/49] END knn__n_neighbors=7, pca__n_components=10;, score=0.890 total time=   0.2s
# [CV 2/5; 37/49] START knn__n_neighbors=7, pca__n_components=10..................
# [CV 2/5; 37/49] END knn__n_neighbors=7, pca__n_components=10;, score=0.927 total time=   0.2s
# [CV 3/5; 37/49] START knn__n_neighbors=7, pca__n_components=10..................
# [CV 3/5; 37/49] END knn__n_neighbors=7, pca__n_components=10;, score=0.918 total time=   0.2s
# [CV 4/5; 37/49] START knn__n_neighbors=7, pca__n_components=10..................
# [CV 4/5; 37/49] END knn__n_neighbors=7, pca__n_components=10;, score=0.910 total time=   0.2s
# [CV 5/5; 37/49] START knn__n_neighbors=7, pca__n_components=10..................
# [CV 5/5; 37/49] END knn__n_neighbors=7, pca__n_components=10;, score=0.918 total time=   0.2s
# [CV 1/5; 38/49] START knn__n_neighbors=7, pca__n_components=15..................
# [CV 1/5; 38/49] END knn__n_neighbors=7, pca__n_components=15;, score=0.902 total time=   0.2s
# [CV 2/5; 38/49] START knn__n_neighbors=7, pca__n_components=15..................
# [CV 2/5; 38/49] END knn__n_neighbors=7, pca__n_components=15;, score=0.920 total time=   0.2s
# [CV 3/5; 38/49] START knn__n_neighbors=7, pca__n_components=15..................
# [CV 3/5; 38/49] END knn__n_neighbors=7, pca__n_components=15;, score=0.908 total time=   0.2s
# [CV 4/5; 38/49] START knn__n_neighbors=7, pca__n_components=15..................
# [CV 4/5; 38/49] END knn__n_neighbors=7, pca__n_components=15;, score=0.902 total time=   0.2s
# [CV 5/5; 38/49] START knn__n_neighbors=7, pca__n_components=15..................
# [CV 5/5; 38/49] END knn__n_neighbors=7, pca__n_components=15;, score=0.932 total time=   0.2s
# [CV 1/5; 39/49] START knn__n_neighbors=7, pca__n_components=20..................
# [CV 1/5; 39/49] END knn__n_neighbors=7, pca__n_components=20;, score=0.897 total time=   0.2s
# [CV 2/5; 39/49] START knn__n_neighbors=7, pca__n_components=20..................
# [CV 2/5; 39/49] END knn__n_neighbors=7, pca__n_components=20;, score=0.916 total time=   0.2s
# [CV 3/5; 39/49] START knn__n_neighbors=7, pca__n_components=20..................
# [CV 3/5; 39/49] END knn__n_neighbors=7, pca__n_components=20;, score=0.921 total time=   0.2s
# [CV 4/5; 39/49] START knn__n_neighbors=7, pca__n_components=20..................
# [CV 4/5; 39/49] END knn__n_neighbors=7, pca__n_components=20;, score=0.901 total time=   0.2s
# [CV 5/5; 39/49] START knn__n_neighbors=7, pca__n_components=20..................
# [CV 5/5; 39/49] END knn__n_neighbors=7, pca__n_components=20;, score=0.924 total time=   0.2s
# [CV 1/5; 40/49] START knn__n_neighbors=7, pca__n_components=25..................
# [CV 1/5; 40/49] END knn__n_neighbors=7, pca__n_components=25;, score=0.913 total time=   0.2s
# [CV 2/5; 40/49] START knn__n_neighbors=7, pca__n_components=25..................
# [CV 2/5; 40/49] END knn__n_neighbors=7, pca__n_components=25;, score=0.921 total time=   0.2s
# [CV 3/5; 40/49] START knn__n_neighbors=7, pca__n_components=25..................
# [CV 3/5; 40/49] END knn__n_neighbors=7, pca__n_components=25;, score=0.917 total time=   0.2s
# [CV 4/5; 40/49] START knn__n_neighbors=7, pca__n_components=25..................
# [CV 4/5; 40/49] END knn__n_neighbors=7, pca__n_components=25;, score=0.901 total time=   0.2s
# [CV 5/5; 40/49] START knn__n_neighbors=7, pca__n_components=25..................
# [CV 5/5; 40/49] END knn__n_neighbors=7, pca__n_components=25;, score=0.927 total time=   0.2s
# [CV 1/5; 41/49] START knn__n_neighbors=7, pca__n_components=30..................
# [CV 1/5; 41/49] END knn__n_neighbors=7, pca__n_components=30;, score=0.901 total time=   0.3s
# [CV 2/5; 41/49] START knn__n_neighbors=7, pca__n_components=30..................
# [CV 2/5; 41/49] END knn__n_neighbors=7, pca__n_components=30;, score=0.914 total time=   0.3s
# [CV 3/5; 41/49] START knn__n_neighbors=7, pca__n_components=30..................
# [CV 3/5; 41/49] END knn__n_neighbors=7, pca__n_components=30;, score=0.921 total time=   0.3s
# [CV 4/5; 41/49] START knn__n_neighbors=7, pca__n_components=30..................
# [CV 4/5; 41/49] END knn__n_neighbors=7, pca__n_components=30;, score=0.890 total time=   0.3s
# [CV 5/5; 41/49] START knn__n_neighbors=7, pca__n_components=30..................
# [CV 5/5; 41/49] END knn__n_neighbors=7, pca__n_components=30;, score=0.925 total time=   0.3s
# [CV 1/5; 42/49] START knn__n_neighbors=7, pca__n_components=35..................
# [CV 1/5; 42/49] END knn__n_neighbors=7, pca__n_components=35;, score=0.887 total time=   0.4s
# [CV 2/5; 42/49] START knn__n_neighbors=7, pca__n_components=35..................
# [CV 2/5; 42/49] END knn__n_neighbors=7, pca__n_components=35;, score=0.912 total time=   0.3s
# [CV 3/5; 42/49] START knn__n_neighbors=7, pca__n_components=35..................
# [CV 3/5; 42/49] END knn__n_neighbors=7, pca__n_components=35;, score=0.916 total time=   0.3s
# [CV 4/5; 42/49] START knn__n_neighbors=7, pca__n_components=35..................
# [CV 4/5; 42/49] END knn__n_neighbors=7, pca__n_components=35;, score=0.906 total time=   0.4s
# [CV 5/5; 42/49] START knn__n_neighbors=7, pca__n_components=35..................
# [CV 5/5; 42/49] END knn__n_neighbors=7, pca__n_components=35;, score=0.912 total time=   0.3s
# [CV 1/5; 43/49] START knn__n_neighbors=8, pca__n_components=5...................
# [CV 1/5; 43/49] END knn__n_neighbors=8, pca__n_components=5;, score=0.864 total time=   0.2s
# [CV 2/5; 43/49] START knn__n_neighbors=8, pca__n_components=5...................
# [CV 2/5; 43/49] END knn__n_neighbors=8, pca__n_components=5;, score=0.902 total time=   0.1s
# [CV 3/5; 43/49] START knn__n_neighbors=8, pca__n_components=5...................
# [CV 3/5; 43/49] END knn__n_neighbors=8, pca__n_components=5;, score=0.901 total time=   0.2s
# [CV 4/5; 43/49] START knn__n_neighbors=8, pca__n_components=5...................
# [CV 4/5; 43/49] END knn__n_neighbors=8, pca__n_components=5;, score=0.902 total time=   0.2s
# [CV 5/5; 43/49] START knn__n_neighbors=8, pca__n_components=5...................
# [CV 5/5; 43/49] END knn__n_neighbors=8, pca__n_components=5;, score=0.918 total time=   0.2s
# [CV 1/5; 44/49] START knn__n_neighbors=8, pca__n_components=10..................
# [CV 1/5; 44/49] END knn__n_neighbors=8, pca__n_components=10;, score=0.894 total time=   0.1s
# [CV 2/5; 44/49] START knn__n_neighbors=8, pca__n_components=10..................
# [CV 2/5; 44/49] END knn__n_neighbors=8, pca__n_components=10;, score=0.912 total time=   0.2s
# [CV 3/5; 44/49] START knn__n_neighbors=8, pca__n_components=10..................
# [CV 3/5; 44/49] END knn__n_neighbors=8, pca__n_components=10;, score=0.914 total time=   0.2s
# [CV 4/5; 44/49] START knn__n_neighbors=8, pca__n_components=10..................
# [CV 4/5; 44/49] END knn__n_neighbors=8, pca__n_components=10;, score=0.914 total time=   0.1s
# [CV 5/5; 44/49] START knn__n_neighbors=8, pca__n_components=10..................
# [CV 5/5; 44/49] END knn__n_neighbors=8, pca__n_components=10;, score=0.917 total time=   0.1s
# [CV 1/5; 45/49] START knn__n_neighbors=8, pca__n_components=15..................
# [CV 1/5; 45/49] END knn__n_neighbors=8, pca__n_components=15;, score=0.901 total time=   0.2s
# [CV 2/5; 45/49] START knn__n_neighbors=8, pca__n_components=15..................
# [CV 2/5; 45/49] END knn__n_neighbors=8, pca__n_components=15;, score=0.906 total time=   0.2s
# [CV 3/5; 45/49] START knn__n_neighbors=8, pca__n_components=15..................
# [CV 3/5; 45/49] END knn__n_neighbors=8, pca__n_components=15;, score=0.914 total time=   0.2s
# [CV 4/5; 45/49] START knn__n_neighbors=8, pca__n_components=15..................
# [CV 4/5; 45/49] END knn__n_neighbors=8, pca__n_components=15;, score=0.918 total time=   0.2s
# [CV 5/5; 45/49] START knn__n_neighbors=8, pca__n_components=15..................
# [CV 5/5; 45/49] END knn__n_neighbors=8, pca__n_components=15;, score=0.916 total time=   0.2s
# [CV 1/5; 46/49] START knn__n_neighbors=8, pca__n_components=20..................
# [CV 1/5; 46/49] END knn__n_neighbors=8, pca__n_components=20;, score=0.902 total time=   0.2s
# [CV 2/5; 46/49] START knn__n_neighbors=8, pca__n_components=20..................
# [CV 2/5; 46/49] END knn__n_neighbors=8, pca__n_components=20;, score=0.913 total time=   0.2s
# [CV 3/5; 46/49] START knn__n_neighbors=8, pca__n_components=20..................
# [CV 3/5; 46/49] END knn__n_neighbors=8, pca__n_components=20;, score=0.910 total time=   0.1s
# [CV 4/5; 46/49] START knn__n_neighbors=8, pca__n_components=20..................
# [CV 4/5; 46/49] END knn__n_neighbors=8, pca__n_components=20;, score=0.906 total time=   0.2s
# [CV 5/5; 46/49] START knn__n_neighbors=8, pca__n_components=20..................
# [CV 5/5; 46/49] END knn__n_neighbors=8, pca__n_components=20;, score=0.932 total time=   0.2s
# [CV 1/5; 47/49] START knn__n_neighbors=8, pca__n_components=25..................
# [CV 1/5; 47/49] END knn__n_neighbors=8, pca__n_components=25;, score=0.898 total time=   0.2s
# [CV 2/5; 47/49] START knn__n_neighbors=8, pca__n_components=25..................
# [CV 2/5; 47/49] END knn__n_neighbors=8, pca__n_components=25;, score=0.912 total time=   0.2s
# [CV 3/5; 47/49] START knn__n_neighbors=8, pca__n_components=25..................
# [CV 3/5; 47/49] END knn__n_neighbors=8, pca__n_components=25;, score=0.920 total time=   0.2s
# [CV 4/5; 47/49] START knn__n_neighbors=8, pca__n_components=25..................
# [CV 4/5; 47/49] END knn__n_neighbors=8, pca__n_components=25;, score=0.899 total time=   0.1s
# [CV 5/5; 47/49] START knn__n_neighbors=8, pca__n_components=25..................
# [CV 5/5; 47/49] END knn__n_neighbors=8, pca__n_components=25;, score=0.918 total time=   0.3s
# [CV 1/5; 48/49] START knn__n_neighbors=8, pca__n_components=30..................
# [CV 1/5; 48/49] END knn__n_neighbors=8, pca__n_components=30;, score=0.890 total time=   0.3s
# [CV 2/5; 48/49] START knn__n_neighbors=8, pca__n_components=30..................
# [CV 2/5; 48/49] END knn__n_neighbors=8, pca__n_components=30;, score=0.906 total time=   0.3s
# [CV 3/5; 48/49] START knn__n_neighbors=8, pca__n_components=30..................
# [CV 3/5; 48/49] END knn__n_neighbors=8, pca__n_components=30;, score=0.920 total time=   0.3s
# [CV 4/5; 48/49] START knn__n_neighbors=8, pca__n_components=30..................
# [CV 4/5; 48/49] END knn__n_neighbors=8, pca__n_components=30;, score=0.901 total time=   0.2s
# [CV 5/5; 48/49] START knn__n_neighbors=8, pca__n_components=30..................
# [CV 5/5; 48/49] END knn__n_neighbors=8, pca__n_components=30;, score=0.923 total time=   0.2s
# [CV 1/5; 49/49] START knn__n_neighbors=8, pca__n_components=35..................
# [CV 1/5; 49/49] END knn__n_neighbors=8, pca__n_components=35;, score=0.889 total time=   0.2s
# [CV 2/5; 49/49] START knn__n_neighbors=8, pca__n_components=35..................
# [CV 2/5; 49/49] END knn__n_neighbors=8, pca__n_components=35;, score=0.902 total time=   0.2s
# [CV 3/5; 49/49] START knn__n_neighbors=8, pca__n_components=35..................
# [CV 3/5; 49/49] END knn__n_neighbors=8, pca__n_components=35;, score=0.921 total time=   0.2s
# [CV 4/5; 49/49] START knn__n_neighbors=8, pca__n_components=35..................
# [CV 4/5; 49/49] END knn__n_neighbors=8, pca__n_components=35;, score=0.902 total time=   0.2s
# [CV 5/5; 49/49] START knn__n_neighbors=8, pca__n_components=35..................
# [CV 5/5; 49/49] END knn__n_neighbors=8, pca__n_components=35;, score=0.912 total time=   0.2s
# Precisión: 91.1% con {'knn__n_neighbors': 3, 'pca__n_components': 15}

# %% [markdown]
# También podríamos probar diferentes funciones de distancia [sklearn distances](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.distance_metrics.html#sklearn.metrics.pairwise.distance_metrics) a emplear en el parámetro "metric". Así mismo podríamos explorar el parámetro "weights" que pondera el voto de cada vecino de forma diferente según el parámetro escogido.
#
# **Ejercicio:** prueba también diferentes métricas y "weights" junto con todo lo anterior. Emplea el BayessianOpt visto en la práctica anterior.

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.1-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.4.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-24.4.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (24.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.5.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-24.4.0 scikit-optimize-0.10.1

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures;
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.decomposition import PCA;
from sklearn.pipeline import Pipeline;

knn = KNeighborsClassifier();

pipe = Pipeline(steps=[("scaler", scaler),("pca", pca),("knn", knn)])


G = {"pca__n_components": Integer(1,57),"knn__n_neighbors" : Integer(1,20), "knn__metric": Categorical(["l1", "l2"]), "knn__weights": Categorical(["uniform","distance"])}
#l1 es distancia manhattan y l2 es distancia euclidea

BS = BayesSearchCV(pipe, G, scoring='accuracy', n_iter=20, refit=True, cv=5)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# Precisión: 92.9% con OrderedDict([('knn__metric', 'l2'), ('knn__n_neighbors', 20), ('knn__weights', 'distance'), ('pca__n_components', 19)])

# %% [markdown]
# ## Olivetti Faces
#
# Prueba ahora el clasificador KNN junto con todos los parámetros y preprocesos que creas convenientes sobre el dataset de reconocimiento facial de Olivetti.

# %%
from sklearn.datasets import fetch_openml
from sklearn.datasets import fetch_olivetti_faces
from sklearn.model_selection import train_test_split


knn = KNeighborsClassifier();

pipe = Pipeline(steps=[("scaler", scaler),("pca", pca),("knn", knn)])

X, y = fetch_olivetti_faces(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)





GS = GridSearchCV(KNeighborsClassifier(), pipe, G, scoring='accuracy', refit=True, cv=5)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures;
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.decomposition import PCA;
from sklearn.pipeline import Pipeline;
from sklearn.datasets import fetch_olivetti_faces
from sklearn.model_selection import train_test_split

X, y = fetch_olivetti_faces(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)

knn = KNeighborsClassifier();

pipe = Pipeline(steps=[("scaler", scaler),("pca", pca),("knn", knn)])


G = {"pca__n_components": Integer(1,57),"knn__n_neighbors" : Integer(1,20), "knn__metric": Categorical(["l1", "l2"]), "knn__weights": Categorical(["uniform","distance"])}
#l1 es distancia manhattan y l2 es distancia euclidea

BS = BayesSearchCV(pipe, G, scoring='accuracy', n_iter=20, refit=True, cv=5)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /root/scikit_learn_data
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-18-5e8405a8598a> in <cell line: 9>()
#       7 from sklearn.model_selection import train_test_split
#       8
# ----> 9 X, y = fetch_olivetti_faces(return_X_y=True)
#      10 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)
#      11
#
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_olivetti_faces.py in fetch_olivetti_faces(data_home, shuffle, random_state, download_if_missing, return_X_y)
#     115
#     116         print("downloading Olivetti faces from %s to %s" % (FACES.url, data_home))
# --> 117         mat_path = _fetch_remote(FACES, dirname=data_home)
#     118         mfile = loadmat(file_name=mat_path)
#     119         # delete raw .mat data
#
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_base.py in _fetch_remote(remote, dirname)
#    1322
#    1323     file_path = remote.filename if dirname is None else join(dirname, remote.filename)
# -> 1324     urlretrieve(remote.url, file_path)
#    1325     checksum = _sha256(file_path)
#    1326     if remote.checksum != checksum:
#
# /usr/lib/python3.10/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     239     url_type, path = _splittype(url)
#     240
# --> 241     with contextlib.closing(urlopen(url, data)) as fp:
#     242         headers = fp.info()
#     243
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden
